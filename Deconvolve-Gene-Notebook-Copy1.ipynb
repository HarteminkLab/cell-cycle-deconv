# %% [markdown]
# # Python deconvolution of a single gene
#
# In this notebook, we will test the deconvolution of a single gene's gene expression.
#
# The goal is to verify that the deconvolution has been successfully ported from the matlab code base.
#
#
#
# This example uses the gene expression data from the Xin Guo 2011 paper (referring to the Orlando 2008 dataset).
#
# We will call this the Xin 2011 dataset though because we will be validating against his deconvolution results.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from config import Config
from model import Model

from config import load_xg_gene_expression_config

# %%
from config import load_yl_replicate2_gene_expression_config

# %%
yl2_config = load_yl_replicate2_gene_expression_config()
yl2_model = Model(yl2_config, 'EDC1', 0.00429)

yl2_model.deconvolve()
plt.plot(yl2_model.f.value)

# %%
og_config = load_xg_gene_expression_config()
og_model = Model(og_config, 'EDC1', 0.00429)

og_model.deconvolve()
plt.plot(og_model.f.value)
