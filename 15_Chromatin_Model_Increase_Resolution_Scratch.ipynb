# %% [markdown]
# # Experiments increasing the resolution of the chromatin deconvolution
# February 12, 2024
#
# In this notebook, we will deconvolve the chromatin, and identify the limits to increasing the resolution of the deconvolution. The timing of the model should scale proportional to the input size.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cc_src.chromatin_model import ChromatinModel
from src.config import load_yl_replicate1_rg1_alpha_vst_config

gene_name = 'CLB2'
config1 = load_yl_replicate1_rg1_alpha_vst_config()
chromatin_model = ChromatinModel(config1)
chromatin_model.load_mnase_gene(gene_name, 1)
# Out:
# Loading MNase reads for CLB2...Done.
# The histogram shape around the TSS is: (3, 9)
# The shape of the flattened grid to be deconvolved is: (16, 27)
# Applying normalization using scaling matrix: output/mnase/rep1_len_scaling_3len_bins.csv
# The shape of the flattened grid to be deconvolved is: (16, 27)

# %%
y_bins = np.arange(0, 225, 10)
x_bin_size = 10
promoter_bins = 24
gene_body_bins = 40


chromatin_model.define_histogram_bins(x_bin_size, promoter_bins, gene_body_bins, 
    y_bins=y_bins)
chromatin_model.create_bins_per_all_sample()
# Out:
# The histogram shape around the TSS is: (22, 65)

# %%
chromatin_model.smooth_bins()

# %%
g_kernel = create_2d_gaussian_kernel(k_size=60, sigma=0.75, plot=True)

# %%
from scipy.ndimage import zoom
from scipy.signal import convolve2d
from src.preprocessing import create_2d_gaussian_kernel

xbins = np.arange(*chromatin_model.mnase_span)
ybins = np.arange(0, 225)

n = len(chromatin_model.timepoints)
target_rows, target_cols = (6, 18)
resized_data = np.zeros((n, target_rows, target_cols))

for time_idx in range(n):

    sample = chromatin_model.timepoints[time_idx]

    plotting_reads, hist, \
        x_edges, y_edges = chromatin_model.compute_bin_counts_sample(sample, xbins, ybins)
    hist = hist.T

    subs_matrix = np.zeros((target_rows, target_cols))

    bin_size_row = hist.shape[0] / target_rows
    bin_size_col = hist.shape[1] / target_cols

    for i in range(target_rows):
        for j in range(target_cols):
            # Calculate the start and end indices for the current bin
            row_start = int(np.floor(i * bin_size_row))
            row_end = int(np.floor((i + 1) * bin_size_row))
            col_start = int(np.floor(j * bin_size_col))
            col_end = int(np.floor((j + 1) * bin_size_col))

            # Aggregate the values within this bin (mean, sum, etc.)
            subs_matrix[i, j] = np.sum(hist[row_start:row_end, col_start:col_end])

    resized_data[time_idx] = subs_matrix

# %%
plt.figure(figsize=(9, 1))

vmax = 0.25

plt.subplot(1, 3, 1)
plt.imshow(hist, aspect='auto', cmap='magma_r', vmax=vmax, origin='lower')

plt.subplot(1, 3, 2)
plt.imshow(smoothed_img, aspect='auto', cmap='magma_r', vmax=vmax, origin='lower')

plt.subplot(1, 3, 3)
plt.imshow(resized_data[-1], aspect='auto', cmap='magma_r', origin='lower')

# %%
plt.figure(figsize=(9, 2))
plt.subplot(1, 2, 1)
plt.hist(chromatin_model.unsmoothed_all_hists.flatten())

plt.subplot(1, 2, 2)
plt.hist(resized_data.flatten())
# Out:
# (array([1288.,  246.,   96.,   48.,   29.,    9.,    4.,    3.,    3.,
#            2.]),
#  array([  0. ,  57.6, 115.2, 172.8, 230.4, 288. , 345.6, 403.2, 460.8,
#         518.4, 576. ]),
#  <BarContainer object of 10 artists>)

# %%
# Let's test our new resized data with the deconvolution:
chromatin_model.all_hists = resized_data

# %%
chromatin_model.create_deconvolution_matrices(False)
# Out:
# The shape of the flattened grid to be deconvolved is: (16, 108)

# %%
# It's possible we will want to increase the value of the counts on the resized data
# They will probably be very small (on the scale of 0-1)
# When previously, we were deconvolving values from 0-100 (dependent on the size
# of the bins)

# %%
chromatin_model.deconv_hist.shape
# Out:
# (16, 1430)

# %%
chromatin_model.gamma = 0.00001
chromatin_model.deconvolve(solver='MOSEK', verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Feb 12 05:13:26 PM: Your problem has 24516 variables, 1 constraints, and 0 parameters.
# (CVXPY) Feb 12 05:13:26 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 12 05:13:26 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 12 05:13:26 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 12 05:13:26 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 12 05:13:26 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Feb 12 05:13:26 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Feb 12 05:13:26 PM: Applying reduction Dcp2Cone
# (CVXPY) Feb 12 05:13:26 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 12 05:13:26 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 12 05:13:27 PM: Applying reduction MOSEK
# (CVXPY) Feb 12 05:13:28 PM: Finished problem compilation (took 2.269e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 12 05:13:28 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Feb 12 05:13:29 PM: Problem
# (CVXPY) Feb 12 05:13:29 PM:   Name                   :
# (CVXPY) Feb 12 05:13:29 PM:   Objective sense        : maximize
# (CVXPY) Feb 12 05:13:29 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Feb 12 05:13:29 PM:   Constraints            : 107461
# (CVXPY) Feb 12 05:13:29 PM:   Affine conic cons.     : 0
# (CVXPY) Feb 12 05:13:29 PM:   Disjunctive cons.      : 0
# (CVXPY) Feb 12 05:13:29 PM:   Cones                  : 1
# (CVXPY) Feb 12 05:13:29 PM:   Scalar variables       : 192134
# (CVXPY) Feb 12 05:13:29 PM:   Matrix variables       : 0
# (CVXPY) Feb 12 05:13:29 PM:   Integer variables      : 0
# (CVXPY) Feb 12 05:13:29 PM:
# (CVXPY) Feb 12 05:13:29 PM: Optimizer started.
# (CVXPY) Feb 12 05:13:30 PM: Presolve started.
# (CVXPY) Feb 12 05:13:30 PM: Linear dependency checker started.
# (CVXPY) Feb 12 05:13:30 PM: Linear dependency checker terminated.
# (CVXPY) Feb 12 05:13:30 PM: Eliminator started.
# (CVXPY) Feb 12 05:13:30 PM: Freed constraints in eliminator : 79704
# (CVXPY) Feb 12 05:13:30 PM: Eliminator terminated.
# (CVXPY) Feb 12 05:13:31 PM: Eliminator started.
# (CVXPY) Feb 12 05:13:31 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 12 05:13:31 PM: Eliminator terminated.
# (CVXPY) Feb 12 05:13:31 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Feb 12 05:13:31 PM: Lin. dep.  - tries                  : 1                 time                   : 0.05
# (CVXPY) Feb 12 05:13:31 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Feb 12 05:13:31 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Feb 12 05:13:31 PM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Feb 12 05:13:31 PM: Presolve terminated. Time: 1.15
# (CVXPY) Feb 12 05:13:31 PM: Optimizer  - threads                : 8
# (CVXPY) Feb 12 05:13:31 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Feb 12 05:13:31 PM: Optimizer  - Constraints            : 27757
# (CVXPY) Feb 12 05:13:31 PM: Optimizer  - Cones                  : 1
# (CVXPY) Feb 12 05:13:31 PM: Optimizer  - Scalar variables       : 90830             conic                  : 1730
# (CVXPY) Feb 12 05:13:31 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Feb 12 05:13:31 PM: Factor     - setup time             : 0.55
# (CVXPY) Feb 12 05:13:31 PM: Factor     - dense det. time        : 0.00              GP order time          : 0.00
# (CVXPY) Feb 12 05:13:31 PM: Factor     - nonzeros before factor : 3.22e+06          after factor           : 3.22e+06
# (CVXPY) Feb 12 05:13:31 PM: Factor     - dense dim.             : 2                 flops                  : 8.68e+08
# (CVXPY) Feb 12 05:13:31 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Feb 12 05:13:31 PM: 0   1.0e+00  2.0e+00  2.0e+00  0.00e+00   -1.000000000e+00  -0.000000000e+00  1.0e+00  2.05
# (CVXPY) Feb 12 05:13:32 PM: 1   5.3e-01  1.1e+00  1.3e+00  -7.62e-01  3.164640901e+01   3.198915864e+01   5.3e-01  2.16
# (CVXPY) Feb 12 05:13:32 PM: 2   3.4e-01  6.8e-01  7.8e-01  -4.67e-01  1.431199552e+02   1.431910848e+02   3.4e-01  2.21
# (CVXPY) Feb 12 05:13:32 PM: 3   2.3e-01  4.7e-01  2.0e-01  1.31e+00   3.372669255e+02   3.377078627e+02   2.3e-01  2.26
# (CVXPY) Feb 12 05:13:32 PM: 4   1.6e-01  3.3e-01  9.8e-02  1.12e+00   4.557200532e+02   4.559886930e+02   1.6e-01  2.31
# (CVXPY) Feb 12 05:13:32 PM: 5   8.1e-02  1.6e-01  2.3e-02  2.78e+00   5.220928000e+02   5.221548115e+02   8.1e-02  2.37
# (CVXPY) Feb 12 05:13:32 PM: 6   2.8e-02  5.6e-02  4.1e-03  2.03e+00   5.481147995e+02   5.481279934e+02   2.8e-02  2.42
# (CVXPY) Feb 12 05:13:32 PM: 7   1.3e-02  2.5e-02  1.3e-03  1.10e+00   5.505163674e+02   5.505224155e+02   1.3e-02  2.48
# (CVXPY) Feb 12 05:13:32 PM: 8   3.5e-03  7.0e-03  4.0e-04  4.66e-01   5.472114599e+02   5.472133030e+02   3.5e-03  2.55
# (CVXPY) Feb 12 05:13:32 PM: 9   7.2e-04  1.4e-03  9.7e-05  -2.02e-01  5.372962392e+02   5.372942944e+02   7.2e-04  2.66
# (CVXPY) Feb 12 05:13:32 PM: 10  1.8e-04  3.6e-04  3.1e-05  -3.76e-01  5.185810294e+02   5.185753297e+02   1.8e-04  2.76
# (CVXPY) Feb 12 05:13:32 PM: 11  6.7e-05  1.3e-04  1.3e-05  -4.06e-01  4.951049391e+02   4.950961455e+02   6.7e-05  2.87
# (CVXPY) Feb 12 05:13:32 PM: 12  1.7e-05  3.4e-05  3.9e-06  -3.40e-01  4.477851317e+02   4.477728993e+02   1.7e-05  2.98
# (CVXPY) Feb 12 05:13:32 PM: 13  5.8e-06  1.2e-05  1.3e-06  -1.71e-01  3.997443529e+02   3.997324278e+02   5.8e-06  3.09
# (CVXPY) Feb 12 05:13:33 PM: Optimizer terminated. Time: 3.18
# (CVXPY) Feb 12 05:13:33 PM:
# (CVXPY) Feb 12 05:13:33 PM:
# (CVXPY) Feb 12 05:13:33 PM: Interior-point solution summary
# (CVXPY) Feb 12 05:13:33 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Feb 12 05:13:33 PM:   Solution status : OPTIMAL
# (CVXPY) Feb 12 05:13:33 PM:   Primal.  obj: 3.9974435290e+02    nrm: 3e+04    Viol.  con: 2e-08    var: 3e+01    cones: 0e+00
# (CVXPY) Feb 12 05:13:33 PM:   Dual.    obj: 3.9973242782e+02    nrm: 2e+03    Viol.  con: 0e+00    var: 1e-12    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 12 05:13:33 PM: Problem status: optimal
# (CVXPY) Feb 12 05:13:33 PM: Optimal value: 3.921e+02
# (CVXPY) Feb 12 05:13:33 PM: Compilation took 2.269e+00 seconds
# (CVXPY) Feb 12 05:13:33 PM: Solver (including time spent in interface) took 4.696e+00 seconds
# Deconvolved in : 00:00:07.79
# The fitting norm is 3.63, the smoothing norm is: 4.93

# %%
chromatin_model.f.shape
# Out:
# (227, 108)

# %%
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(vmax=200)

# %%
fig = chromatin_model.plot_prediction_comparison(vmax=300)
