# %% [markdown]
# # Gene-level - Deconvolved Chromatin Analysis
#
# - Focus on chromatin dynamics related to genes
# - Linkage to expression, save for later.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %config Completer.use_jedi = False

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pipeline.genelevel_chromatin_analysis import GeneChromatinAnalysis

# Test running the script to create plots from start to finish

output_directory = 'output/prototype_pipeline_subset'

# Create analysis object
analyzer = GeneChromatinAnalysis(output_directory, 
    chromatin_data_directory='chromatin_deconvolution_no_daughter',
    save_directory='genelevel_chromatin_no_daughter')

# %%
analyzer.run_all_analyses()
# Out:
# Starting complete polar analysis...
# Initializing chromatin analysis... copy correction: True
# Loading configs from replication runs:  output/prototype_pipeline_subset/single_replication/
# Shifting mu0, gamma1, and gamma2, for alpha...
# Creating directory: output/prototype_pipeline_subset/genelevel_chromatin_no_daughter...Directory exists. Skipping.
# Loading genomic data directory: output/prototype_pipeline_subset/chromatin_deconvolution_no_daughter/deconvolution_data
# Will save chromatin measures to: output/prototype_pipeline_subset/genelevel_chromatin_no_daughter
# Loading chromatin measures
# Loading precomputed chromatin measures, from output/prototype_pipeline_subset/genelevel_chromatin_no_daughter
# Initializing genome deconvolution analysis...
# All analyses initialized successfully
# Creating polar datasets...
# Filtered to 5578 common ORFs across all datasets
# Polar datasets created successfully
# Plotting PTR sensitivity analysis...
# Interesting threshold values:
# ...

# %%
plt.figure(figsize=(4, 4))
plt.scatter(analyzer.entropies_polar_data_df.ptr, analyzer.small_polar_data_df.ptr,
           s=1, alpha=0.1)
plt.xlim(0.9, 1.8)
plt.ylim(0.9, 1.8)
plt.ylabel("Promoter PTR")
plt.xlabel("Entropy PTR")
# Out:
# Text(0.5, 0, 'Entropy PTR')

# %%
plots_dir = f'{output_directory}/genelevel_chromatin_no_daughter/'
save_dir = plots_dir

# %%
from pipeline.genelevel_chromatin_analysis import layout_figure_plots
layout_figure_plots(plots_dir, save_dir)
# Out:
# Debug figure saved to: output/prototype_pipeline_subset/genelevel_chromatin_no_daughter//Figure_2_debug.png
# Clean figure saved to: output/prototype_pipeline_subset/genelevel_chromatin_no_daughter//Figure_2.png

# %%
from IPython.display import Image, display
display(Image(f'{plots_dir}/Figure_2_debug.png'))
display(Image(f'{plots_dir}/Figure_2.png'))

# %%
from pipeline.genelevel_chromatin_analysis import layout_supplemental_2
layout_supplemental_2(plots_dir, save_dir)

from IPython.display import Image, display
display(Image(f'{plots_dir}/Supplemental_S2_debug.png'))
# Out:
# Debug figure saved to: output/prototype_pipeline_subset/genelevel_chromatin_no_daughter//Supplemental_S2_debug.png
# Clean figure saved to: output/prototype_pipeline_subset/genelevel_chromatin_no_daughter//Supplemental_S2.png

# %%
display(Image(f'{plots_dir}/Supplemental_S2.png'))
