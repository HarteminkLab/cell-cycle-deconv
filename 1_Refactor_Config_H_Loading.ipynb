# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.rg1_refactor import RG1Model
from src.global_config import GlobalConstants

rg1_model = RG1Model()
rg1_model.load_from_posteriors('data/2019_cloccs_fits/yl_2019_replicate1/posteriors.txt',
                              GlobalConstants.CHROM_WT1_TIMEPOINTS)
rg1_model.calculate_H()

# %%
rg1_model.params_dic
# Out:
# {'mu0': -26.7901,
#  'delta': 8.1805,
#  'sigma0': 10.9885,
#  'sigmav': 0.1424,
#  'lambda': 68.1914,
#  'gamma1': 0.0041,
#  'gamma2': 0.2547,
#  'halted': 0.2245}

# %%
plt.imshow(rg1_model.H, vmax=0.1)

# %%
rg1_model.params_dic['gamma1'] = 0.0
rg1_model.params_dic['mu0'] = -21
rg1_model.update_timepoints()
rg1_model.calculate_H()
plt.imshow(rg1_model.H, vmax=0.1)

# %%
rg1_model.branch_Hpos_df.loc['t'].loc['CG1']
# Out:
#        Hpos  timepoint
# phase
# CG1      23   0.000000
# CG1      24   0.929883
# CG1      25   1.859765
# CG1      26   2.789648
# CG1      27   3.719531
# CG1      28   4.649414
# CG1      29   5.579296
# CG1      30   6.509179
# CG1      31   7.439062
# CG1      32   8.368945
# CG1      33   9.298827
# CG1      34  10.228710
# CG1      35  11.158593
# CG1      36  12.088475
# CG1      37  13.018358
# CG1      38  13.948241
# CG1      39  14.878124
# CG1      40  15.808006
# CG1      41  16.737889
# CG1      42  17.667772
# CG1      43  18.597655
# CG1      44  19.527537
# CG1      45  20.457420
