# %% [markdown]
# # Figure 2 - Replication Deconvolution

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.Figure2_Replication import Figure2ReplicationDeconvolution

output_dir = 'output/draft3_run/'
fig2 = Figure2ReplicationDeconvolution(output_dir)

# %%
# Create a figure depicting the objective NHFB = G

# %%
# Examine the replication data, does replicate 2's cell cycle length need to be longer?
from src.CombinedReplicateDeconvolutionRunner import CombinedReplicateDeconvolutionRunner
from src.config import load_default_chrom_configs

config1, config2 = load_default_chrom_configs()
runner = CombinedReplicateDeconvolutionRunner(chrom=4, save_dir=None, 
    config1=config1, config2=config2)
# Out:
# Omit windows with less than 75% read coverage.
# Omit windows with less than 75% read coverage.

# %%
runner.start_runs(num_epochs=1)
# Out:
# Deconvolving 700 regions
# Initializing B using timepoint 0
# Deconvolving 700 regions
# Initializing B using timepoint 0
# H, G, N, B shapes: (31, 109) (31, 700) (31, 31) (700, 700)
# Running initial combined deconvolution for F, N, and B
# Epoch: 0
# [0]: Running iterative updates and combined deconvolution for F, N, and B
# 00:00:31.243
# mu0_1        -26.790100
# delta_1        8.180500
# sigma0_1      10.988500
# sigmav_1       0.142400
# lambda_1      68.191400
# gamma1_1       0.004100
# gamma2_1       0.254700
# halted_1       0.224500
# mu0_2        -20.151000
# delta_2       10.895300
# sigma0_2      10.631000
# sigmav_2       0.129700
# lambda_2      60.209300
# gamma1_2       0.001700
# gamma2_2       0.283700
# halted_2       0.290600
# opt_H_rn_1     0.003689
# opt_H_rn_2     0.002831
# F_rn           0.003274
# Name: 0, dtype: float64

# %%
masked_indices_combined = runner.deconvolution.retrieve_masked_indices()

# %%
fig = runner.deconvolution.plot_N_G_Fr_B_diagram()

# %%
fig = runner.deconvolution.plot_G_N_H_Fr_B_diagram()
