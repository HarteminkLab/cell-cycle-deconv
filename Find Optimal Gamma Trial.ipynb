# %% [markdown]
# # Find Optimal Gamma
#
# Find the optimal gamma values using the ported Matlab code
#
# First with gene expression.
#
# Then with chromatin

# %%
# Now let's see how the H matrix looks

from src.config import Config, load_yl_replicate2_rg1_config
from src.model import Model

config = load_yl_replicate2_rg1_config()
model = Model(config, 'CLB2', gamma=0.00730)
# Out:
# Initial branch: Recovery shape:  (14, 49)
# Initial branch: postG1 shape:  (14, 79)

# %%
from src.find_gamma import FindOptimalGamma

find_gamma = FindOptimalGamma(model)

# %%
find_gamma.find_optimal()
# Out:
# findOptimal
#   ... base_rn = 1.2158
#   ... gamma in [0.0010, 0.0100]
#   ...  search left, rn_goal = 1.2958, rate = 6.6
#   ...  search right, rn_goal = 1.7021, rate = 40.0
#   ... rn range: [1.3326, 1.6915]
#   ... search gamma in [0.0010 0.0100] for elbow
#   ...   gamma = 0.001, rn = 1.333, sn = 41.13
#   ...   gamma = 0.0019, rn = 1.377, sn = 30.25
#   ...   gamma = 0.0028, rn = 1.412, sn = 22.23
#   ...   gamma = 0.0037, rn = 1.452, sn = 17.8
#   ...   gamma = 0.0046, rn = 1.511, sn = 12.92
#   ...   gamma = 0.0055, rn = 1.537, sn = 11.62
#   ...   gamma = 0.0064, rn = 1.56, sn = 10.51
#   ...   gamma = 0.0073, rn = 1.576, sn = 10.37
#   ...   gamma = 0.0082, rn = 1.617, sn = 10.19
#   ...   gamma = 0.0091, rn = 1.653, sn = 9.854
#   ...   gamma = 0.01, rn = 1.691, sn = 9.052
# The x_grad1 is: [0.04470783 0.03995138 0.03728219 0.04921982 0.04264003 0.02433506
#  0.01964091 0.02894939 0.03849993 0.03700749 0.03809233]
# The x_grad2 is: [-0.00475645 -0.00371282  0.00463422  0.00267892 -0.01244238 -0.01149956
#   0.00230717  0.00942951  0.00402905 -0.0002038   0.00108484]
# The curvature is: [ 9.43333090e-06  6.85193445e-05  4.89112944e-04  8.87862314e-04
#   1.19821094e-03  9.27629383e-03  4.73824905e-02  1.55744478e+00
#  -3.86708813e-01 -5.51775995e-02 -1.55102137e-02]
# YPR119W: ... final gamma = 0.00730
# Time to find optimal gamma: 00:00:06.07
# (1,
#  array([1.3325684 , 1.37727623, 1.41247116, 1.45184062, 1.5109108 ,
#         1.53712067, 1.55958092, 1.57640249, 1.6174797 , 1.65340235,
#         1.69149468]),
#  array([41.12756991, 30.25141374, 22.23241363, 17.7962328 , 12.91596461,
#         11.6214759 , 10.5119036 , 10.36861703, 10.18909937,  9.85429745,
#          9.05227553]),
#  array([0.001 , 0.0019, 0.0028, 0.0037, 0.0046, 0.0055, 0.0064, 0.0073,
#         0.0082, 0.0091, 0.01  ]),
#  0.007300000000000002)

# %%
model.plot_deconvolved_gene()
