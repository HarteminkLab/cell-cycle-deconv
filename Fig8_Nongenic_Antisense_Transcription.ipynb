# %% [markdown]
# # Supplemental Analyses - Nongenic/Antisense Transcripts Panel

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.figure_antisense_nongenic import FigureNongenicTranscripts

# Initialize and automatically load all data
fig_nongenic = FigureNongenicTranscripts('output/draft4_run/')
# Out:
# Creating directory: output/draft4_run//nongenic_antisense_figures...Directory exists. Skipping.
# Loading expression data...
# Loaded 9663 transcripts
#   5774 genic transcripts
#   3889 non-genic transcripts
# Loading deconvolved gene expression data...
# Loading deconvolved expression files, n= 9663
# Loaded expression data: 9663 transcripts, 257 timepoints
# Setting a minimum transcription level: The 50th percentile of the average gene expression:  3.4745508100860008
# Loading chromatin metrics...
# Loading saved data from output/draft4_run//chromatin_metrics...
#   Loading deconvolved data...
#     Loaded promoter_occupancy: 9663 genes, 257 timepoints
#     Loaded nucleosome_entropy: 9663 genes, 257 timepoints
#     Loaded nucleosome_occupancy: 9663 genes, 257 timepoints
#     Loaded promoter_occupancy PTRs: 9663 genes
#     Loaded nucleosome_entropy PTRs: 9663 genes
#     Loaded nucleosome_occupancy PTRs: 9663 genes
#   Loading raw_rep1 data...
# ...

# %%
fig_nongenic.create_plots()
# Out:
# Filtered 3315 nongenic transcripts with criteria:
# Minimum expression level: 3.4745508100860008
# Minimum PTR: 0
#   Kept: 254
#   Removed: 3061
#   Antisense transcripts: 111
#   Divergent transcripts: 75
#   Antisense & Divergent: 42
# 24 transcripts with >95 percentile PTR (all transcription)
# Saved figure to: output/draft4_run//nongenic_antisense_figures/nongenic_ptrs.png
# Number of total factors profiled by Rossi:  319
# Number of TFs selected by GO terms (GO:0016563,GO:0043565):  166
# Number of TFs with Rossi binding sites:  76
#    of these, Kelliher cell-cycle TFS:  12
# Creating directory: output/draft4_run//rna_seq_intermediate...Directory exists. Skipping.
# Creating directory: output/draft4_run//rna_seq_intermediate/reads...Directory exists. Skipping.
# Creating directory: output/draft4_run//rna_seq_intermediate/pileups...Directory exists. Skipping.
# Initialized RNASeqIntermediateManager for chromosome 4
# ...

# %%
fig_nongenic.layout_panel()
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental10_Nongenic_transcription_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental10_Nongenic_transcription.png
# Uppercase figure saved to: output/draft4_run//Figures/Uppercase/Supplemental10_Nongenic_transcription.png

# %%
from IPython.display import Image

display(Image('output/draft4_run/Figures/Debug/Supplemental10_Nongenic_transcription_debug.png'))

# %%
fig_nongenic.plot_transcript_length_distributions()
# Out:
# Saved figure to: output/draft4_run//nongenic_antisense_figures/transcript_length_distributions.png

# %%
fig_nongenic.plot_divergent_nongenic_ptrs()
# Out:
# Saved figure to: output/draft4_run//nongenic_antisense_figures/divergent_genes_scatter.png

# %%
fig_nongenic.plot_TSS_update_examples()
# Out:
# Number of total factors profiled by Rossi:  319
# Number of TFs selected by GO terms (GO:0016563,GO:0043565):  166
# Number of TFs with Rossi binding sites:  76
#    of these, Kelliher cell-cycle TFS:  12
# Creating directory: output/draft4_run//rna_seq_intermediate...Directory exists. Skipping.
# Creating directory: output/draft4_run//rna_seq_intermediate/reads...Directory exists. Skipping.
# Creating directory: output/draft4_run//rna_seq_intermediate/pileups...Directory exists. Skipping.
# Initialized RNASeqIntermediateManager for chromosome 2
# Intermediate directory: output/draft4_run//rna_seq_intermediate
# Loaded pileups from watson_rna_seq_pileup_rep1_chr2.h5, crick_rna_seq_pileup_rep1_chr2.h5
# Shape: (16, 813184) (timepoints x positions)
# Loaded pileups from watson_rna_seq_pileup_rep2_chr2.h5, crick_rna_seq_pileup_rep2_chr2.h5
# Shape: (14, 813184) (timepoints x positions)
# Saved figure to: output/draft4_run//nongenic_antisense_figures/updated_TSS_example1.png
# ...

# %%
fig_nongenic.plot_divergent_locus_examples()
# Out:
# Number of total factors profiled by Rossi:  319
# Number of TFs selected by GO terms (GO:0016563,GO:0043565):  166
# Number of TFs with Rossi binding sites:  76
#    of these, Kelliher cell-cycle TFS:  12
# Creating directory: output/draft4_run//rna_seq_intermediate...Directory exists. Skipping.
# Creating directory: output/draft4_run//rna_seq_intermediate/reads...Directory exists. Skipping.
# Creating directory: output/draft4_run//rna_seq_intermediate/pileups...Directory exists. Skipping.
# Initialized RNASeqIntermediateManager for chromosome 16
# Intermediate directory: output/draft4_run//rna_seq_intermediate
# Loaded pileups from watson_rna_seq_pileup_rep1_chr16.h5, crick_rna_seq_pileup_rep1_chr16.h5
# Shape: (16, 948066) (timepoints x positions)
# Loaded pileups from watson_rna_seq_pileup_rep2_chr16.h5, crick_rna_seq_pileup_rep2_chr16.h5
# Shape: (14, 948066) (timepoints x positions)
# Replace old latex preamble params:
# ...

# %%
from IPython.display import Image
fig_nongenic.layout_supplemental_divergent_scatter()
display(Image('output/draft4_run/Figures/Debug/Supplemental10.5_Nongenic_Divergent_debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental10.5_Nongenic_Divergent_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental10.5_Nongenic_Divergent.png
# Uppercase figure saved to: output/draft4_run//Figures/Uppercase/Supplemental10.5_Nongenic_Divergent.png

# %%
from IPython.display import Image
fig_nongenic.layout_supplemental_TSSes()
display(Image('output/draft4_run/Figures/Debug/Supplemental11_TSS_update_debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental11_TSS_update_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental11_TSS_update.png
# Uppercase figure saved to: output/draft4_run//Figures/Uppercase/Supplemental11_TSS_update.png
