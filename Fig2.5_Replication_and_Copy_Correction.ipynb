# %% [markdown]
# # Figure 2.5 - Replication Deconvolution Results and Copy Correction
#
# This notebook combines with the Figure 2 notebook. I refactored the figures a bit. So the separation is not ideal. But here is the current setup:
#
# Notebook Figure 2: Shows the replication and copy correction setup figures
# Notebook Figure 2.5: Shows the replication estimation and copy correction results. And combines the resulting plots into a combined figure.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.FigureCopyCorrection import FigureCopyCorrection

fig4 = FigureCopyCorrection(output_directory='output/draft4_run/')
fig4.load_copy_correction()
# Out:
# Creating directory: output/draft4_run//fig_copy_correction...Directory exists. Skipping.
# Filtering the called replication timings to 1.0 percentile (highest timing indicative of poor fit)
# Filtered timings from 5482 to 5370
# Number of regions removed: 112
# Correlation between muller and replication timing model: 0.87
# Chromosome 1...Skipped 0 entries
# 00:00:03.704
# Chromosome 2...Skipped 0 entries
# 00:00:14.765
# Chromosome 3...Skipped 0 entries
# 00:00:17.366
# Chromosome 4...Skipped 0 entries
# 00:01:17.300
# Chromosome 5...Skipped 0 entries
# 00:01:22.573
# Chromosome 6...Skipped 0 entries
# 00:01:24.885
# Chromosome 7...Skipped 0 entries
# 00:01:41.490
# Chromosome 8...Skipped 0 entries
# 00:01:46.705
# Chromosome 9...Skipped 0 entries
# 00:01:51.011
# Chromosome 10...Skipped 0 entries
# 00:02:00.779
# Chromosome 11...Skipped 1 entries
# 00:02:16.590
# Chromosome 12...Skipped 0 entries
# 00:02:36.240
# Chromosome 13...Skipped 0 entries
# 00:02:46.900
# ...

# %%
fig4.copy_correction_analysis.initialize_replication_time_colormaps()

# %%
fig4.copy_correction_analysis.select_example_windows()

# %%
fig4.plot_all()
# Out:
# Saved figure to: output/draft4_run//fig_copy_correction/Replication_Timing_chr4.png
# Saved figure to: output/draft4_run//fig_copy_correction/Replication_Timing_correlation.png
# Saved figure to: output/draft4_run//fig_copy_correction/Copy_Correction_PTRs.png
# Saved figure to: output/draft4_run//fig_copy_correction/Copy_Correction_Examples.png

# %%
from IPython.display import Image, display

fig4.layout_panel()
display(Image(f'{fig4.figures_dir}/Debug/Figure2_Replication_Copy_Correction_Debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Figure2_Replication_Copy_Correction_debug.png
# Clean figure saved to: output/draft4_run//Figures/Figure2_Replication_Copy_Correction.png
# Uppercase figure saved to: output/draft4_run//Figures/Uppercase/Figure2_Replication_Copy_Correction.png

# %%
fig4.layout_supplemental_panel()

display(Image(f'{fig4.figures_dir}/Debug/Supplemental2.5_Replication_Detail_Debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental2.5_Replication_Detail_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental2.5_Replication_Detail.png
# Uppercase figure saved to: output/draft4_run//Figures/Uppercase/Supplemental2.5_Replication_Detail.png
