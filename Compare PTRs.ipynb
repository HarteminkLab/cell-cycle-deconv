# %% [markdown]
# # Compare the peak to trough ratios of our deconvolution runs
#
# 1. Load the model
# 2. Load the raw data
# 3. Load the deconvolved data
# 4. Compute the peak to trough ratio
# 5. Load the published peak to trough ratio values
# 6. Plot the comparison between the peak to trough ratios

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cc_src.deconvolution_model import DeconvolvedAnalysis
from src.config import Config, load_xg_gene_expression_config
from src.model import Model

# %%
gene_name = 'EDC1'
gamma = 0.004

config = load_xg_gene_expression_config()

# This is a little wonky, but we have two implementations of models
# and we're still in the process of merging/refactoring them together

model = Model(config, gene_name, gamma)

deconvolved_analysis = DeconvolvedAnalysis(model)

# %%
deconvolved_analysis.plot_deconvolved_gene(gene_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 deconvolved_analysis.plot_deconvolved_gene(gene_name)
#
# File ~/Research/deconvolution-python/cc_src/deconvolution_model.py:52, in plot_deconvolved_gene(self, gene_name, title)
#      47 g.shape
#      49 H = self.H
#      51 # Just take half of H, as we are only using one replicate
# ---> 52 # TODO: Revisit this
#      53 half_H = H[0:g.shape[1]]
#      55 f.shape, half_H.T.shape,
#
# File ~/Research/deconvolution-python/cc_src/sgd.py:57, in get_orfname(gene_name)
#      56 def get_orfname(gene_name):
# ---> 57     gene = get_gene(gene_name)
#      58     return gene['orf_name']
#
# File ~/Research/deconvolution-python/cc_src/sgd.py:52, in get_gene(gene_name)
#      51 def get_gene(gene_name):
# ---> 52     genes = read_sgd_genes()
#      53     found_genes = genes[(genes['gene'] == gene_name) | (genes.index == gene_name)]
#      54     return found_genes.reset_index().loc[0]
#
# File ~/Research/deconvolution-python/cc_src/sgd.py:30, in read_sgd_genes(filename)
#      27 def read_sgd_genes(filename='data/sgd_R64-1-1_20110208.gff'):
#      28     """Read sgd orf/genes file as tsv file from gff file with fasta data removed."""
# ---> 30     data = pd.read_csv(filename, sep='\t', skiprows=19,
#      31                               names=["chr", "source", "cat", "start", "stop", ".",
#      32                                   "strand", "", "desc"])
#      33     data = data[data.columns[[0, 2, 3, 4, 6, 8]]]
#      34     data.columns = ["chr", "cat", "start", "stop", "strand", "desc"]
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/sgd_R64-1-1_20110208.gff'
