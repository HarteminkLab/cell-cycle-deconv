# %% [markdown]
# # Create animation profiles for Combined Model
# March 8, 2024
#
# Compare the animation profiles for cell cycling and non-cell cycle genes

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from cc_src.combined_chromatin_model import load_chromatin_model_from_disk

chromatin_dir = 'output/deconvolve_combined_g006_2024_03_08_dg1_fix/chromatin/'
gene_name = 'AIM1'

chromatin_model = load_chromatin_model_from_disk(gene_name, chromatin_dir)
# Out:
# Loading MNase reads for YAL046C/AIM1...Loading chromosome reads: 1
# Done.

# %%
from src.heatmap_animator import FHeatmapAnimator

animator = FHeatmapAnimator(chromatin_model)

# %%
animator.create_animation('output/aim1.gif')
# Out:
# Creating directory: tmp/frames...Directory exists. Skipping.

# %%
from IPython.display import Image
import time

gif_path = 'output/aim1.gif'
gif_url = f"{gif_path}?{time.time()}" # bypass cached image
Image(url=gif_url) # display image
# Out:
# <img src="output/aim1.gif?1709932854.568634"/>
