# %% [markdown]
# # Notebook to incorporate the halted cells parameter
#
# This notebook is the first notebook to test out the halted cells proportion. Although now every subsequent deconvolution run will have this halted modeling procedure built-in

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.config import load_combined_yl_alpha_vst_gene_expression_config, \
    load_yl_replicate2_rg1_alpha_vst_config, load_yl_replicate1_rg1_alpha_vst_config

from src.model import Model

config1 = load_yl_replicate1_rg1_alpha_vst_config()
config2 = load_yl_replicate2_rg1_alpha_vst_config()
combined_config = load_combined_yl_alpha_vst_gene_expression_config()

# %%
gene_name = "RNR1"
model1 = Model(config1, gene_name, 0.0001)
model1.deconvolve_find_optimal_gamma()
model1.plot_deconvolved_gene()

# %%
model2 = Model(config2, gene_name, 0.0006)
model2.deconvolve_find_optimal_gamma()
model2.plot_deconvolved_gene()

# %%
model = Model(combined_config, gene_name, 0.0006)
model.deconvolve_find_optimal_gamma()
model.plot_deconvolved_gene()

# %%
gene_name = "DSE1"
model1 = Model(config1, gene_name, 0.0001)
model1.deconvolve_find_optimal_gamma()
model1.plot_deconvolved_gene()

# %%
model2 = Model(config2, gene_name, 0.0006)
model2.deconvolve_find_optimal_gamma()
model2.plot_deconvolved_gene()

# %%
model = Model(combined_config, gene_name, 0.0006)
model.deconvolve_find_optimal_gamma()
model.plot_deconvolved_gene()

# %%
gene_name = "CLB2"
model1 = Model(config1, gene_name, 0.0001)
model1.deconvolve_find_optimal_gamma()
model1.plot_deconvolved_gene()

model2 = Model(config2, gene_name, 0.0006)
model2.deconvolve_find_optimal_gamma()
model2.plot_deconvolved_gene()

model = Model(config, gene_name, 0.0006)
model.deconvolve_find_optimal_gamma()
model.plot_deconvolved_gene()

# %%
gene_name = "DSE2"
model1 = Model(config1, gene_name, 0.0007)
model1.deconvolve_find_optimal_gamma()
model1.deconvolve()
model1.plot_deconvolved_gene()
