# %% [markdown]
# # Figure 4: Chromatin and Replication
#
# **Goal:**
# Present the story that best conveys the relationship between changing entropy and replication timing.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
