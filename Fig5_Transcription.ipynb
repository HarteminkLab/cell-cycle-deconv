# %% [markdown]
# # Figure 5 - Transcription-linked Chromatin Deconvolution Results

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.figure_chromatin_metrics import FigureChromatinMetrics

fig_metrics = FigureChromatinMetrics(output_dir='output/draft4_run/')

# %%
fig_metrics.setup_processor()
fig_metrics.setup_integration()
# Out:
# Starting full expression analysis workflow...
# Loaded 9663 transcripts
#   5774 genic transcripts
#   3889 non-genic transcripts
# Loading deconvolved gene expression data...
# Loaded expression data: 7633 transcripts, 257 timepoints
# Computing PTR values with quantiles 0.1-0.9...
# Computed PTR values for 7633 transcripts
# PTR range: 1.000 - 8.477
# Filtered to 5702 genic transcripts
# Genic PTR range: 1.000 - 8.477
# Identified 571 top cycling genes
# PTR threshold: 1.167
# Top cycling PTR range: 1.167 - 8.477
# Full analysis complete!
# Summary: 571 top cycling genes identified from 5702 genic transcripts
# Loading saved data from output/draft4_run//chromatin_metrics...
#   Loading deconvolved data...
#     Loaded promoter_occupancy: 9663 genes, 257 timepoints
#     Loaded nucleosome_entropy: 9663 genes, 257 timepoints
#     Loaded nucleosome_occupancy: 9663 genes, 257 timepoints
#     Loaded promoter_occupancy PTRs: 9663 genes
#     Loaded nucleosome_entropy PTRs: 9663 genes
# ...

# %%
fig_metrics.generate_figures_and_panel()
# Out:
# Creating individual chromatin metrics plots...
# Creating directory: output/draft4_run//chromatin_metrics/figures...Directory exists. Skipping.
# Saved figure to: output/draft4_run//chromatin_metrics/figures/promoter_occupancy_ptr.png
# Saved figure to: output/draft4_run//chromatin_metrics/figures/nucleosome_entropy_ptr.png
# Saved figure to: output/draft4_run//chromatin_metrics/figures/nucleosome_occupancy_ptr.png
# Saved figure to: output/draft4_run//chromatin_metrics/figures/raw_vs_deconvolved_all_metrics_ptrs.png
# Saved figure to: output/draft4_run/chromatin_metrics/figures/combined_ptrs_w_top_expression.png
# Number of transcripts in 90th percentile: 571
# Saved figure to: output/draft4_run/chromatin_metrics/figures/expression_ptrs.png
# Individual plots saved to: output/draft4_run/chromatin_metrics/figures
# Saved figure to: output/draft4_run/chromatin_metrics/figures/expression_chromatin_raw_rep1_scatter.png
# ...

# %%
fig = fig_metrics.integration.plot_single_metric_three_replicates('CLB5', 'nucleosome_occupancy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('CLB5', 'nucleosome_entropy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('CLB5', 'promoter_occupancy')

# %%
fig = fig_metrics.integration.plot_single_metric_three_replicates('THI22', 'nucleosome_occupancy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('THI22', 'nucleosome_entropy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('THI22', 'promoter_occupancy')

# %%
fig = fig_metrics.integration.plot_single_metric_three_replicates('CLB1', 'nucleosome_occupancy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('CLB1', 'nucleosome_entropy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('CLB1', 'promoter_occupancy')

# %%
#fig_metrics.layout_supplemental_panel()

# %%
from IPython.display import Image, display
display(Image(f'output/draft4_run/Figures/Supplemental_Chromatin_Metrics_debug.png'))

# %%
processor.compute_entropy_shift_values_quantile()
processor.plot_chromatin_value_range()

# %%
# Normalize entropy by shifting the range of values down such that
# the lowest 1% of values are 0.

# %%
updated_ptrs = fig_metrics.chromatin_processor.compute_peak_to_trough_values(
    fig_metrics.chromatin_processor.deconvolved_chromatin_metrics,
    'deconvolved')

# %%
fig = fig_metrics.integration.plot_single_metric_three_replicates('TOS4', 'nucleosome_occupancy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('TOS4', 'nucleosome_entropy')
fig = fig_metrics.integration.plot_single_metric_three_replicates('TOS4', 'promoter_occupancy')
