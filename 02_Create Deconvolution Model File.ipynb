# %% [markdown]
# # Create Deconvolution Model Files for Replicate 1 and 2

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.create_models import create_wt1_model, create_wt2_model

alpha = 0
modelfile1 = create_wt1_model(f'models/yl_cell_cycle/wt1_rg1.{alpha}.label', alpha)
modelfile2 = create_wt2_model(f'models/yl_cell_cycle/wt2_rg1.{alpha}.label', alpha)

alpha = 26
modelfile1 = create_wt1_model(f'models/yl_cell_cycle/wt1_rg1.{alpha}.label', alpha)
modelfile2 = create_wt2_model(f'models/yl_cell_cycle/wt2_rg1.{alpha}.label', alpha)

# From the parameter search
modelfile1 = create_wt1_model(f'models/yl_cell_cycle/wt1_rg1.{30}.label', 30)
modelfile2 = create_wt2_model(f'models/yl_cell_cycle/wt2_rg1.{17}.label', 17)
# Out:
# Created model and saved to file: models/yl_cell_cycle/wt1_rg1.0.label
# Created model and saved to file: models/yl_cell_cycle/wt2_rg1.0.label
# Created model and saved to file: models/yl_cell_cycle/wt1_rg1.26.label
# Created model and saved to file: models/yl_cell_cycle/wt2_rg1.26.label
# Created model and saved to file: models/yl_cell_cycle/wt1_rg1.30.label
# Created model and saved to file: models/yl_cell_cycle/wt2_rg1.17.label

# %%
from src.ModelFile import ModelFile

model_file_loaded = ModelFile()
model_file_loaded.load_model(modelfile2)

model_file_loaded.plot_model()
