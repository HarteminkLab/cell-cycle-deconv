# %% [markdown]
# # Supplemental Figures
#
# Various supplemental figures that are not tied to any existing analysis figures set.
# 1. Flow cytometry data

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.supplemental_figures import FigureSupplemental

sup_figs = FigureSupplemental('output/draft4_run/')
# Out:
# Creating directory: output/draft4_run//supplemental_various...Directory exists. Skipping.

# %%
from IPython.display import Image, display
sup_figs.layout_supplemental_flow_cytometry()
display(Image('output/draft4_run/Figures/Debug/Supplemental1_flow_cytometry_debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental1_flow_cytometry_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental1_flow_cytometry.png

# %%
sup_figs.layout_supplemental_cloccs_fits()
display(Image('output/draft4_run/Figures/Debug/Supplemental2_fit_curves_debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental2_fit_curves_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental2_fit_curves.png

# %%
sup_figs.plot_promoter_intergenic_distribution()
# Out:
# There are 1012 genes with promoters less than 200 bp long
# There are 1652 genes with promoters less than 250 bp long
# There are 2389 genes with promoters less than 300 bp long
# Saved figure to: output/draft4_run//supplemental_various/integenic_spacing_distribution.png

# %%
sup_figs.layout_supplemental_promoters()
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental4.5_Intergenic_distribution_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental4.5_Intergenic_distribution.png

# %%
display(Image('output/draft4_run/Figures/Debug/Supplemental4.5_Intergenic_distribution_debug.png'))
