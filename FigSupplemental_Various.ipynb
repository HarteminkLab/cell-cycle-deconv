# %% [markdown]
# # Supplemental Figures
#
# Various supplemental figures that are not tied to any existing analysis figures set.
# 1. Flow cytometry data

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.supplemental_figures import FigureSupplemental

sup_figs = FigureSupplemental('output/draft4_run/')
# Out:
# Creating directory: output/draft4_run//supplemental_various...Directory exists. Skipping.

# %%
sup_figs.layout_supplemental_flow_cytometry()
# Out:
# Debug figure saved to: output/draft4_run//Figures/Supplemental0_flow_cytometry_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental0_flow_cytometry.png

# %%
from IPython.display import Image, display
display(Image('output/draft4_run/Figures/Supplemental0_flow_cytometry_debug.png'))

# %%
sup_figs.layout_supplemental_cloccs_fits()
# Out:
# Debug figure saved to: output/draft4_run//Figures/Supplemental0.1_fit_curves_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental0.1_fit_curves.png

# %%
from IPython.display import Image, display
display(Image('output/draft4_run/Figures/Supplemental0.1_fit_curves_debug.png'))
