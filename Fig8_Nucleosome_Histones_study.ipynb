# %% [markdown]
# # Study of cell cycle nucleosome dynamics
#
# ### Datasets:
# - Chereji nucleosomes positioning
# - Weiner histone modifications (WT)

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.nucleosome_histone_dataset import HistonesNucleosomesDataset

histones_nucleosomes_ref_data = HistonesNucleosomesDataset()

# %%
histones_nucleosomes_ref_data.load_all()
histones_nucleosomes_ref_data.get_summary_stats()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 histones_nucleosomes_ref_data.load_all()
#       2 histones_nucleosomes_ref_data.get_summary_stats()
#
# AttributeError: 'HistonesNucleosomesDataset' object has no attribute 'load_all'
