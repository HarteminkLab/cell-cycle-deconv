# %% [markdown]
# # Figure 5 - Transcription-linked Chromatin Deconvolution Results

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.chromatin_metrics_processor import ChromatinMetricsProcessor

# Chromatin data setup, create datasets for chromatin measures

output_dir = 'output/draft4_run/'
processor = ChromatinMetricsProcessor(output_dir)
processor.setup_data_loaders()

# %%
deconvolved_chromatin_metrics = \
    processor.compute_metrics_for_data(processor.deconvolved_chromatin_loader, debug=True)
# Out:
# Starting metric computation for 9663 transcripts...
# Detected 257 timepoints from sample gene YAL068C
# Processed 200/9663 genes. Time elapsed: 00:00:31.466. Success: 200, Failed: 0
# Completed! Processed 9663 genes in 00:01:13.734. Success: 200, Failed: 0

# %%
processor.compute_chromatin_metrics_all_data(debug=True)
# Out:
# Starting metric computation for 9663 transcripts...
# Detected 257 timepoints from sample gene YAL068C
# Processed 200/9663 genes. Time elapsed: 00:00:30.085. Success: 200, Failed: 0
# Completed! Processed 9663 genes in 00:01:10.107. Success: 200, Failed: 0
# Starting metric computation for 9663 transcripts...
# Detected 16 timepoints from sample gene YAL068C
# Processed 200/9663 genes. Time elapsed: 00:02:19.257. Success: 200, Failed: 0
# Completed! Processed 9663 genes in 00:02:19.351. Success: 200, Failed: 0
# Starting metric computation for 9663 transcripts...
# Detected 15 timepoints from sample gene YAL068C
# Processed 200/9663 genes. Time elapsed: 00:02:24.411. Success: 200, Failed: 0
# Completed! Processed 9663 genes in 00:02:24.505. Success: 200, Failed: 0

# %%
processor.all_transcripts_set
# Out:
#                             chr strand   start    stop  length  \
# YAL068C                       1      -    1807    2169     362
# YAL067W-A                     1      +    2480    2707     227
# YAL067C                       1      -    7235    9016    1781
# YAL065C                       1      -   11565   11951     386
# YAL064W-B                     1      +   12046   12426     380
# ...                         ...    ...     ...     ...     ...
# nogene_chr16_911354_911518   16      -  911354  911518     164
# nogene_chr16_916827_916941   16      -  916827  916941     114
# nogene_chr16_930146_930982   16      -  930146  930982     836
# nogene_chr16_935902_937937   16      -  935902  937937    2035
# nogene_chr16_939606_941076   16      -  939606  941076    1470
#
#                             promoter_start  promoter_end  gene_body_start  \
# YAL068C                               2469          2169             2169
# ...

# %%
import os
save_dir = 'output/draft4_run/chromatin_metrics'
os.mkdir(save_dir)
processor.save_all_results_disk(save_dir)
# Out:
# Saving metrics to output/draft4_run/chromatin_metrics with prefix 'deconvolved'...
#   Saved promoter_occupancy metrics: deconvolved_promoter_occupancy.csv (9663 genes, 257 columns)
#   Saved nucleosome_entropy metrics: deconvolved_nucleosome_entropy.csv (9663 genes, 257 columns)
#   Saved nucleosome_occupancy metrics: deconvolved_nucleosome_occupancy.csv (9663 genes, 257 columns)
# Successfully saved 3 metrics files.
# Saving metrics to output/draft4_run/chromatin_metrics with prefix 'raw_rep1'...
#   Saved promoter_occupancy metrics: raw_rep1_promoter_occupancy.csv (9663 genes, 16 columns)
#   Saved nucleosome_entropy metrics: raw_rep1_nucleosome_entropy.csv (9663 genes, 16 columns)
#   Saved nucleosome_occupancy metrics: raw_rep1_nucleosome_occupancy.csv (9663 genes, 16 columns)
# Successfully saved 3 metrics files.
# Saving metrics to output/draft4_run/chromatin_metrics with prefix 'raw_rep2'...
# ...
