# %% [markdown]
# # Deconvolve the origins of replication
#
# July 1, 2024
#
# ## Goal:
# Show that deconvolution recapituales known origin of replication chromatin dynamics. For at replication origins, the nucleosome-free region (NFR) opens up in G1 allowing the pre-RC licensing and Mcm2-7 bind. At replication time in S-phase, Mcm2-7 unloads to perform helicase functionality for the replication fork. For late replicating origins, this unloading occurs late in S. This is evident in the nucleosome positioning and the origin occupancy dynamics. Show examples of early and late replicating origins in which these dynamics are clear.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.Figure3_Deconvolved_Origins import Figure4DeconvolvedOrigins

figures = Figure4DeconvolvedOrigins()

# %%
figures.plot_heatmap_of_tracking(full=False)

# %%
figures.plot_heatmap_of_tracking()

# %%
# Plot examples of origin occupancies and NFRs to identify good examples
# of origin and NFR timing
figures.plot_heatmap_examples_of_early_late()

# %%
save_dir = 'output/figures/Origin_Deconvolution/'
figures.deconvolve_origins(save_dir)
# Out:
# ARS1623
