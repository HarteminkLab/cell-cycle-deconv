# %% [markdown]
# # Figure 3 - Replication Deconvolution Methodology

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.FigureReplication import FigureReplicationDeconvolution

output_dir = 'output/draft4_run/'
fig2 = FigureReplicationDeconvolution(output_dir)
# Out:
# Creating directory: output/draft4_run//fig_replication...
# Omit windows with less than 75% read coverage.
# Omit windows with less than 75% read coverage.

# %%
# Create a figure depicting the objective NHFB = G
fig2 = fig3
fig2.setup_data()
del fig3
# Out:
# Deconvolving 700 regions
# Initializing B using timepoint 0
# Deconvolving 700 regions
# Initializing B using timepoint 0
# H, G, N, B shapes: (31, 257) (31, 700) (31, 31) (700, 700)
# Running initial combined deconvolution for F, N, and B
# Epoch: 0
# [0]: Running iterative updates and combined deconvolution for F, N, and B
# 00:01:03.545
# mu0_1              -26.790100
# delta_1              8.180500
# sigma0_1            10.988500
# sigmav_1             0.142400
# lambda_1            68.191400
# gamma1_1             0.004100
# gamma2_1             0.254700
# halted_1             0.224500
# num_g1_indices_1    62.000000
# mu0_2              -20.151000
# delta_2             10.895300
# sigma0_2            10.631000
# sigmav_2             0.129700
# lambda_2            60.209300
# gamma1_2             0.001700
# gamma2_2             0.283700
# halted_2             0.290600
# num_g1_indices_2    62.000000
# opt_H_rn_1           0.003837
# opt_H_rn_2           0.002847
# ...

# %%
fig2.plot_all()
# Out:
# Saved figure to: output/draft4_run//fig_replication/Replication_components.png
# Saved figure to: output/draft4_run//fig_replication/Replication_diagram.png
# Saved figure to: output/draft4_run//fig_replication/DNA_replication_diagram.png

# %%
from IPython.display import Image, display

fig2.layout_panel()
display(Image(f'{fig2.figures_dir}/Figure2_Replication_debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Figure2_Replication_debug.png
# Clean figure saved to: output/draft4_run//Figures/Figure2_Replication.png
