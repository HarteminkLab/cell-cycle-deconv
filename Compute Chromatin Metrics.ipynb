# %% [markdown]
# # Notebook to create the chromatin measures for small factor and nucleosome occupancy for deconvolution
#
# We will read in the MNase-seq bam files collect the promoter and gene body fragments then compute
#
# 1. Small fragment promoter occupancy
# 2. Nucleosome fragment promoter occupancy
# 3. Small fragment gene body occupancy
# 4. Nucleosome fragment gene body occupancy
#
# - Promoter will be defined as: [-300, TSS]
# - The gene body will be defined as: [TSS, +500]

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.chromatin_metrics import ChromatinMetrics, yl_rep2_len_spans

small_frag_span, mid_frag_span, nucleosome_len_span = yl_rep2_len_spans()

filename = '../_archive/data/bam/cell_cycle/mnase/DMAH64_MNase_rep1_0_min.bam'
sample_name = 0

chromatin_metrics = ChromatinMetrics(nucleosome_len_span, mid_frag_span, small_frag_span)
chromatin_metrics.read_bam_file(filename, sample_name)

# %%
chromatin_metrics.plot_len_dist()

# %%
# Example plot of a gene and its counts
chromatin_metrics.set_chrom(1)
gene = chromatin_metrics.chrom_genes.iloc[10]
chromatin_metrics.plot_mnase_gene(gene)

# %%
# Run on all genes, all rep2 filenames and save to disk
# Skip this if this has already been done to save time
#
#
# Uncomment this, if the metrics needs to be recomputed
# from src.chromatin_metrics import compute_rep2_chrom_metrics
# compute_rep2_chrom_metrics()

# %%
from src.timer import Timer
from src.read_bam import read_mnase_bam
from src.mnase_reads import save_mnase_reads

# Let's store the MNase-seq into a pandas dataframe for quicker read access for plotting.

replicate2_filenames = [(0, '../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam'),
                         (10, '../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam'),
                         (20, '../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam'),
                         (30, '../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam'),
                         (40, '../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam'),
                         (50, '../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam'),
                         (60, '../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam'),
                         (70, '../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam'),
                         (80, '../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam'),
                         (90, '../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam'),
                         (100, '../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam'),
                         (110, '../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam'),
                         (120, '../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam'),
                         (130, '../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam'),
                         (140, '../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam')]

save_filename = 'output/yl_rep2_mnase_reads.hdf'

# Gene counts for all time points
all_fragments = pd.DataFrame()
chroms = range(1, 17)

# Timer initialization
timer = Timer()
timer.start()

for chrom in range(1, 17):

    print(f"Creating MNase-seq file for chromosome {chrom}")
    chrom_reads = pd.DataFrame()
    
    # Iterate through each bam file/timepoint
    for timepoint, filename in replicate2_filenames:

        print(f"Load MNase-seq for time point {timepoint}, the filepath is: {filename}")

        mnase_reads = read_mnase_bam(filename, sample=timepoint, timer=timer,
                                     chroms=[chrom])
        chrom_reads = pd.concat([chrom_reads, mnase_reads])

    save_mnase_reads(chrom_reads, chrom)
    print(f"\nDone...Elapsed time: {timer.get_time()}")

print(f"Completed in {timer.get_time()}")
# Out:
# Creating MNase-seq file for chromosome 1
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr1.h5 to disk.
#
# Done...Elapsed time: 00:00:23.56
# Creating MNase-seq file for chromosome 2
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr2.h5 to disk.
#
# Done...Elapsed time: 00:02:10.03
# Creating MNase-seq file for chromosome 3
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr3.h5 to disk.
#
# Done...Elapsed time: 00:02:49.39
# Creating MNase-seq file for chromosome 4
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr4.h5 to disk.
#
# Done...Elapsed time: 00:06:10.39
# Creating MNase-seq file for chromosome 5
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr5.h5 to disk.
#
# Done...Elapsed time: 00:07:30.17
# Creating MNase-seq file for chromosome 6
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr6.h5 to disk.
#
# Done...Elapsed time: 00:08:03.43
# Creating MNase-seq file for chromosome 7
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr7.h5 to disk.
#
# Done...Elapsed time: 00:10:27.65
# Creating MNase-seq file for chromosome 8
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr8.h5 to disk.
#
# Done...Elapsed time: 00:11:37.71
# Creating MNase-seq file for chromosome 9
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr9.h5 to disk.
#
# Done...Elapsed time: 00:12:32.72
# Creating MNase-seq file for chromosome 10
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr10.h5 to disk.
#
# Done...Elapsed time: 00:14:05.08
# Creating MNase-seq file for chromosome 11
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr11.h5 to disk.
#
# Done...Elapsed time: 00:15:33.01
# Creating MNase-seq file for chromosome 12
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr12.h5 to disk.
#
# Done...Elapsed time: 00:18:27.08
# Creating MNase-seq file for chromosome 13
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr13.h5 to disk.
#
# Done...Elapsed time: 00:20:24.68
# Creating MNase-seq file for chromosome 14
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr14.h5 to disk.
#
# Done...Elapsed time: 00:21:57.95
# Creating MNase-seq file for chromosome 15
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr15.h5 to disk.
#
# Done...Elapsed time: 00:24:17.00
# Creating MNase-seq file for chromosome 16
# Load MNase-seq for time point 0, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH82_MNase_rep2_0_min.bam
# Load MNase-seq for time point 10, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH83_MNase_rep2_10_min.bam
# Load MNase-seq for time point 20, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH84_MNase_rep2_20_min.bam
# Load MNase-seq for time point 30, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH85_MNase_rep2_30_min.bam
# Load MNase-seq for time point 40, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH86_MNase_rep2_40_min.bam
# Load MNase-seq for time point 50, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH87_MNase_rep2_50_min.bam
# Load MNase-seq for time point 60, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH88_MNase_rep2_60_min.bam
# Load MNase-seq for time point 70, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH89_MNase_rep2_70_min.bam
# Load MNase-seq for time point 80, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH90_MNase_rep2_80_min.bam
# Load MNase-seq for time point 90, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH91_MNase_rep2_90_min.bam
# Load MNase-seq for time point 100, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH92_MNase_rep2_100_min.bam
# Load MNase-seq for time point 110, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH93_MNase_rep2_110_min.bam
# Load MNase-seq for time point 120, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH94_MNase_rep2_120_min.bam
# Load MNase-seq for time point 130, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH95_MNase_rep2_130_min.bam
# Load MNase-seq for time point 140, the filepath is: ../_archive/data/bam/cell_cycle/mnase/DMAH96_MNase_rep2_140_min.bam
# Wrote file: output/yl_rep2_mnase_reads/yl_rep2_mnase_reads_chr16.h5 to disk.
#
# Done...Elapsed time: 00:26:16.00
# Completed in 00:26:16.00

# %% [markdown]
# ## Post processing
#
# After all all chromatin metrics have been computed, we can now make pivot tables for each of the measures,
# basically a matrix of rows (for each gene), columns (for each time point), and cell values of a chromatin measure
#
# Each metric/measure will have its own matrix in the shape of:
#
# (number of genes) x (number of time points)

# %%
all_gene_chrom_occs = pd.read_csv('output/all_chromatin_gene_counts_rep2.csv')
all_gene_chrom_occs = all_gene_chrom_occs.sort_values(['orf_name', 'time'])\
    .set_index(['orf_name', 'time'])
all_gene_chrom_occs.head(5)

# %%
from src.chromatin_metrics import create_save_deconvolution_datasets

# Load the per time per length scaling matrix
scaling_path = 'saved_data/chromatin/yl_rep2_small_promoter_occupancy_for_deconv_'\
    '2023_10_06/yl_rep2_mnase_min_len_scaling_mat.csv'
scaling_counts_df = pd.read_csv(scaling_path).set_index('time')
scaling_counts_df.columns = scaling_counts_df.columns.astype(int)

# Save the individual chromatin matrices to disk
for col in all_gene_chrom_occs.columns[1:]:
    save_filename = f'output/chrom_yl_rep2_{col}.tsv'
        
    # A table of just the chromatin counts as tsv
    counts_df = make_matrix_pvt_df(all_gene_chrom_occs, col)
    counts_normalized_df = normalize_length_dist_pvt(counts_df, scaling_counts_df)
    
    create_save_deconvolution_datasets(counts_normalized_df, col, save_filename)

# %%
from src.sgd import get_orfname

orfname = get_orfname('CLB2')

plt.plot(counts_df.loc[orfname])
plt.plot(counts_normalized_df.loc[orfname])
