# %% [markdown]
# # Python deconvolution of all genes in Yulong's Replicate 2 (2018) gene expression data set, checking timing and concordance with Matlab and published dataset
#
# In this notebook, we will test the deconvolve all of the genes in the Xin Guo 2011 dataset.
#
# The goal is to verify that the deconvolution has been successfully ported from the matlab code base.
#
# We will check the timing and compare the peak to trough values to the published paper dataset.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.model import Model
from src.config import load_yl_replicate2_gene_expression_config

# %%
# Run the model once to get the dimensions of the final output
# TODO: we shouldn't need to do this once the model is read in, but we
# update this later.
config = load_yl_replicate2_gene_expression_config()
model = Model(config, 'CLB1', 0.00429)
model.deconvolve()

# %%
# Load the gene list
genelist = pd.read_csv('allgenes/commongenelist.txt', sep='\t', header=None).values
genelist = genelist.reshape(-1)
genelist
# Out:
# array(['SGV1', 'RTC1', 'SXM1', ..., 'HSP10', 'YLL053C', 'RAD34'],
#       dtype=object)

# %%
from src.timer import Timer

# Initialize configuration and model
timer = Timer()

# We will store all of the deconvolved f values into this matrix
gene_fs = np.zeros((len(genelist), model.f.value.shape[0]))

# %%
# Fixed gamma value for this dataset
gamma = 0.004

print(f"Deconvolving {len(genelist)} genes...")
# Loop through all genes and store the deconvolved f values.
for index in range(len(genelist)):

    gene = genelist[index]

    try:
        og_model = Model(config, gene, gamma)
    except AttributeError:
        print(f"  {gene} was not found. Skipping.")
        continue

    try:
        model.deconvolve()
    except cvxpy.SolverError:
        print(f"  There was an error deconvolving gene: {gene}. Skipping.")
        continue
    
    gene_fs[index] = model.f.value

    if index % 100 == 0:
        print(f"   {index+1}/{len(genelist)} - {timer.get_time()}")
# Out:
# Deconvolving 5670 genes...
#    1/5670 - 00:00:03.00
#    101/5670 - 00:00:56.77
#    201/5670 - 00:01:42.11
#    301/5670 - 00:02:27.00
#    401/5670 - 00:03:11.81
# ORF: YHL009W-B is not found in list of genes data.
#   YHL009W-B was not found. Skipping.
#    501/5670 - 00:03:56.66
#    601/5670 - 00:04:40.92
#    701/5670 - 00:05:25.18
#    801/5670 - 00:06:10.20
#    901/5670 - 00:06:52.83
#    1001/5670 - 00:07:34.77
# ORF: YLR154W-E is not found in list of genes data.
#   YLR154W-E was not found. Skipping.
#    1101/5670 - 00:08:16.22
# ORF: YAR073W is not found in list of genes data.
#   IMD1 was not found. Skipping.
#    1201/5670 - 00:08:57.62
# ORF: YLR154W-F is not found in list of genes data.
#   YLR154W-F was not found. Skipping.
# ORF: YHL009W-A is not found in list of genes data.
#   YHL009W-A was not found. Skipping.
#    1301/5670 - 00:09:38.44
# ORF: YGR226C is not found in list of genes data.
#   YGR226C was not found. Skipping.
#    1401/5670 - 00:10:19.76
#    1501/5670 - 00:11:01.59
#    1601/5670 - 00:11:43.16
#    1701/5670 - 00:12:25.07
#    1801/5670 - 00:13:06.80
#    1901/5670 - 00:18:48.79
# ORF: YIL082W-A is not found in list of genes data.
#   YIL082W-A was not found. Skipping.
#    2001/5670 - 00:19:29.73
#    2101/5670 - 00:20:10.64
#    2201/5670 - 00:20:52.55
#    2301/5670 - 00:21:34.41
# ORF: YBL005W-A is not found in list of genes data.
#   YBL005W-A was not found. Skipping.
#    2401/5670 - 00:22:15.94
# ORF: YDR316W-B is not found in list of genes data.
#   YDR316W-B was not found. Skipping.
#    2501/5670 - 00:22:57.46
# ORF: YML099W-A is not found in list of genes data.
#   YML099W-A was not found. Skipping.
#    2601/5670 - 00:23:39.21
#    2701/5670 - 00:24:21.18
#    2801/5670 - 00:25:03.15
# ORF: YNL067W-A is not found in list of genes data.
#   YNL067W-A was not found. Skipping.
#    2901/5670 - 00:25:44.39
# ORF: YLR312C-B is not found in list of genes data.
#   YLR312C-B was not found. Skipping.
#    3001/5670 - 00:26:25.93
#    3101/5670 - 00:27:07.84
#    3201/5670 - 00:27:49.63
#    3301/5670 - 00:28:31.56
# ORF: YMR013W-A is not found in list of genes data.
#   YMR013W-A was not found. Skipping.
#    3401/5670 - 00:31:01.55
#    3501/5670 - 00:31:42.72
#    3601/5670 - 00:32:23.93
#    3701/5670 - 00:33:05.74
# ORF: YAR010C is not found in list of genes data.
#   YAR010C was not found. Skipping.
# ORF: YAL016C-B is not found in list of genes data.
#   YAL016C-B was not found. Skipping.
#    3801/5670 - 00:33:46.93
# ORF: YBL100W-B is not found in list of genes data.
#   YBL100W-B was not found. Skipping.
# Gene: FRK1 is not found in gene to orf mapping data.
#   FRK1 was not found. Skipping.
#    3901/5670 - 00:34:27.98
# ORF: YAR075W is not found in list of genes data.
#   YAR075W was not found. Skipping.
#    4001/5670 - 00:35:09.50
# ORF: YBL100W-A is not found in list of genes data.
#   YBL100W-A was not found. Skipping.
#    4101/5670 - 00:35:51.16
#    4201/5670 - 00:36:32.95
#    4301/5670 - 00:37:15.03
#    4401/5670 - 00:37:56.83
# ORF: YGR109W-A is not found in list of genes data.
#   YGR109W-A was not found. Skipping.
# ORF: YDR261W-B is not found in list of genes data.
#   YDR261W-B was not found. Skipping.
#    4501/5670 - 00:38:37.69
#    4601/5670 - 00:39:19.65
#    4701/5670 - 00:40:01.37
#    4801/5670 - 00:40:43.30
# ORF: YDR261C-D is not found in list of genes data.
#   YDR261C-D was not found. Skipping.
# ORF: YBR056W-A is not found in list of genes data.
#   YBR056W-A was not found. Skipping.
#    4901/5670 - 00:41:24.32
# ORF: YGR272C is not found in list of genes data.
#   YGR272C was not found. Skipping.
# ORF: YGR045C is not found in list of genes data.
#   YGR045C was not found. Skipping.
#    5001/5670 - 00:44:16.93
# ORF: YGR109W-B is not found in list of genes data.
#   YGR109W-B was not found. Skipping.
#    5101/5670 - 00:44:57.25
#    5201/5670 - 00:45:38.77
#    5301/5670 - 00:48:50.58
# ORF: YJR114W is not found in list of genes data.
#   YJR114W was not found. Skipping.
#    5401/5670 - 00:49:32.95
#    5501/5670 - 00:50:13.73
# ORF: YAR009C is not found in list of genes data.
#   YAR009C was not found. Skipping.
#    5601/5670 - 00:50:55.61
