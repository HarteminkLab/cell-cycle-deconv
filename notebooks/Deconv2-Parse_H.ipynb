# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import torch
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
from pysrc.analyze_models import Model

model = Model()

# %%
import os

model_path = 'models/original_budflow/wt1_budflow/1.1.1.26.label'
model.load_model(model_path)
model.plot_model()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 import os
#       3 model_path = 'models/original_budflow/wt1_budflow/1.1.1.26.label'
# ----> 4 model.load_model(model_path)
#       5 model.plot_model()
#
# File ~/Research/deconvolution-project/notebooks/pysrc/analyze_models.py:11, in Model.load_model(self, model_path)
#       8 def load_model(self, model_path):
#      10     self.model_path = model_path
# ---> 11     with open(model_path, 'r') as f:
#      12         lines = f.readlines()
#      14     line_splits = [[t.strip() for t in line.split(' ')] for line in lines]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/original_budflow/wt1_budflow/1.1.1.26.label'

# %%
import os

model_path = 'models/original_budflow/wt1_budflow/1.1.1.26.label'
model.load_model(model_path)
model.plot_model()

# %% [markdown]
# Initial is
#
# Recovery, Common G1 and postG1
#
# In the model file, R goes from
#
# -mu0 to 26, the alpha value (detachment time?)
#
# Common G1:
#
# 26 to
#
# Need to figure out how these model files are created in the deconvolution code....

# %%
import os

model_path = 'models/yl_cell_cycle/wt1.label'
model.load_model(model_path)
model.plot_model()
