# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams

rcParams['mathtext.it'] = 'Helvetica'
plt.rcParams['mathtext.fontset'] = 'cm'
#      Key mathtext.fontset: 'a' is not a valid value for 
# mathtext.fontset; supported values are ['dejavusans', 'dejavuserif', 
# 'cm', 'stix', 'stixsans', 'custom']
        
plt.figure(figsize=(4, 3))
ax = plt.gca()
ax.set_ylabel(r'$\it{CLB3}$', usetex=True, font='Helvetica')
plt.show()
