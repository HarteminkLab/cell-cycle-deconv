# %% [markdown]
# # Figure 3 - Replication Deconvolution Methodology

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.Figure3_Replication import Figure3ReplicationDeconvolution

output_dir = 'output/draft3_run/'
fig3 = Figure3ReplicationDeconvolution(output_dir)
# Out:
# Creating directory: output/draft3_run//replication_figures...Directory exists. Skipping.
# Omit windows with less than 75% read coverage.
# Omit windows with less than 75% read coverage.

# %%
# Create a figure depicting the objective NHFB = G
fig3.setup_data()
# Out:
# Deconvolving 700 regions
# Initializing B using timepoint 0
# Deconvolving 700 regions
# Initializing B using timepoint 0
# H, G, N, B shapes: (31, 257) (31, 700) (31, 31) (700, 700)
# Running initial combined deconvolution for F, N, and B
# Epoch: 0
# [0]: Running iterative updates and combined deconvolution for F, N, and B
# 00:01:09.885
# mu0_1        -26.790100
# delta_1        8.180500
# sigma0_1      10.988500
# sigmav_1       0.142400
# lambda_1      68.191400
# gamma1_1       0.004100
# gamma2_1       0.254700
# halted_1       0.224500
# mu0_2        -20.151000
# delta_2       10.895300
# sigma0_2      10.631000
# sigmav_2       0.129700
# lambda_2      60.209300
# gamma1_2       0.001700
# gamma2_2       0.283700
# halted_2       0.290600
# opt_H_rn_1     0.003813
# opt_H_rn_2     0.002931
# F_rn           0.003386
# Name: 0, dtype: float64

# %%
fig3.plot_N_G_Fr_B_components()
# Out:
# Saved figure to: output/draft3_run//replication_figures/Replication_components.png

# %%
fig3.plot_GNHFrB_diagram()
# Out:
# Saved figure to: output/draft3_run//replication_figures/Replication_diagram.png

# %%
fig3.plot_diagram_replication()
# Out:
# Saved figure to: output/draft3_run//replication_figures/DNA_replication_diagram.png

# %%
from IPython.display import Image, display

fig3.layout_panel()
display(Image(f'{fig3.save_dir}/Figure3_Replication_debug.png'))
# Out:
# Debug figure saved to: output/draft3_run//replication_figures/Figure3_Replication_debug.png
# Clean figure saved to: output/draft3_run//replication_figures/Figure3_Replication.png

# %%
from src.replication_timing import ReplicationTiming

replication_timings = ReplicationTiming('output/draft3_run/')

# %%
replication_timings.plot_chrom_timing(chrom=4)

replication_timings.plot_muller_correlation()
