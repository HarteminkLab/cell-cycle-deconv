# %% [markdown]
# # Spellman Genes Validation

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.spellman_analysis import SpellmanAnalysis

spellman_analysis = SpellmanAnalysis()
# Out:
# There are 709 Spellman genes.

# %%
spellman_analysis.plot_data()

# %%
spellman_analysis.cluster(k=6)

# %%
spellman_analysis.plot_cluster_maxes(replicate=1)

# %%
spellman_analysis.plot_cluster_maxes(replicate=2)
