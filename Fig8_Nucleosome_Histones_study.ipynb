# %% [markdown]
# # Study of cell cycle nucleosome dynamics
#
# ### Datasets:
# - Chereji nucleosomes positioning
# - Weiner histone modifications (WT)

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.fig_nucleosomes import FigureNucleosomes

# Initialize analyzer
fig_nucleosomes = FigureNucleosomes(
    output_dir="output/draft4_run/",
    window_size=160,
    subset_qval=0.9,
    random_seed=123
)

# %%
fig_nucleosomes.run_full_analysis()
# Out:
# Starting full cell cycle nucleosome analysis...
# ...
# Loading and integrating nucleosome and histone data...
# Loading all Chereji nucleosomes (-1 and +1)...
# Done. 5542 genes with +1 and -1 nucleosomes loaded
# Loading all ~66k Weiner nucleosomes with histone mods...
# Done. 66360 nucleosomes loaded
# Merging Chereji and Weiner nucleosomes, keeping Chereji as canonical...
# Done. Merged into a set of 8760 nucleosomes
# Loading these histones data for these nucleosomes
# Done. Loaded histone data for 8760 nucleosomes
# Loaded 5542 genes with nucleosome data
# Loaded 66360 nucleosomes with histone modifications
# Found 26 histone modifications
# Computing nucleosome metrics across cell cycle timepoints...
# Loading cached nucleosome metrics from disk...
# Computed metrics for 5542 +1 nucleosomes
# Computed metrics for 5542 -1 nucleosomes
# Calculating cyclicity measures (peak-to-trough ratios)...
# Calculated cyclicity measures for 5542 nucleosomes
# ...

# %%
fig_nucleosomes.layout_panel()
# Out:
# Debug figure saved to: output/draft4_run//Figures/Supplemental5.6_Nucleosome_Histones_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental5.6_Nucleosome_Histones.png

# %%
from IPython.display import Image, display
display(Image('output/draft4_run/Figures/Supplemental5.6_Nucleosome_Histones_debug.png'))

# %%
fig_nucleosomes.plot_p1_tss_agreement()
# We can move the histograms and scatter points above to this supplemental including this
# agreement histogram, the main meat of this story is the histone heatmaps.

# %%
from pipeline.fig_nucleosomes import FigureNucleosomes

# Initialize analyzer
fig_nucleosomes_wide_window = FigureNucleosomes("output/draft4_run/")
# Out:
# Creating directory: output/draft4_run//nucleosome_metrics...Directory exists. Skipping.
# Creating directory: output/draft4_run//nucleosome_metrics...Directory exists. Skipping.

# %%
fig_nucleosomes_wide_window.run_full_analysis(force_recompute=False)
# Out:
# Starting full cell cycle nucleosome analysis...
# ...
# Loading and integrating nucleosome and histone data...
# Loading all Chereji nucleosomes (-1 and +1)...
# Done. 5542 genes with +1 and -1 nucleosomes loaded
# Loading all ~66k Weiner nucleosomes with histone mods...
# Done. 66360 nucleosomes loaded
# Merging Chereji and Weiner nucleosomes, keeping Chereji as canonical...
# Done. Merged into a set of 8760 nucleosomes
# Loading these histones data for these nucleosomes
# Done. Loaded histone data for 8760 nucleosomes
# Loaded 5542 genes with nucleosome data
# Loaded 66360 nucleosomes with histone modifications
# Found 26 histone modifications
# Computing nucleosome metrics across cell cycle timepoints...
# Loading cached nucleosome metrics from disk...
# Computed metrics for 5542 +1 nucleosomes
# Computed metrics for 5542 -1 nucleosomes
# Calculating cyclicity measures (peak-to-trough ratios)...
# Calculated cyclicity measures for 5542 nucleosomes
# ...

# %%
from IPython.display import Image, display
fig_nucleosomes_wide_window.layout_panel()
display(Image('output/draft4_run/Figures/Debug/Figure7_Nucleosome_Histones_debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Figure7_Nucleosome_Histones_debug.png
# Clean figure saved to: output/draft4_run//Figures/Figure7_Nucleosome_Histones.png

# %%
fig_nucleosomes_wide_window.layout_supplemental_panel()
display(Image('output/draft4_run/Figures/Debug/Supplemental9_Nucleosome_metrics_debug.png'))
# Out:
# Debug figure saved to: output/draft4_run//Figures/Debug/Supplemental9_Nucleosome_metrics_debug.png
# Clean figure saved to: output/draft4_run//Figures/Supplemental9_Nucleosome_metrics.png
