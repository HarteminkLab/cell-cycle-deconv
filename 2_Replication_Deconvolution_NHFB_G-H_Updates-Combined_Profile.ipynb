# %% [markdown]
# # Chromosome IV - Combined Replication Profile Deconvolution

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.CombinedReplicationDeconvolution import CombinedReplicationDeconvolution
from src.rg1_refactor import load_default_chrom_configs

config1, config2 = load_default_chrom_configs()

combined_deconv = CombinedReplicationDeconvolution(config1=config1, config2=config2,
    chr=4)
# Out:
# Threshold windows with less than 75% read coverage.
# Threshold windows with less than 75% read coverage.

# %%
config1.shift_parameters_for_alpha()
config2.shift_parameters_for_alpha()

# %%
combined_deconv.setup_deconvolution()
# Out:
# Initializing N using config H.
# Initializing B using timepoint 0
# Initializing N using config H.
# Initializing B using timepoint 0

# %%
print("Running initial combined deconvolution for F, N, and B")
result = combined_deconv.iterative_deconvolution_updates(20, verbose=False)
# Out:
# Running initial combined deconvolution for F, N, and B

# %%
plt.imshow(result.Fs[-1])

# %%
epoch_results = combined_deconv.run_epochs(5)
# Out:
# Epoch: 0
# [0]: Running H optimizer for replicate 1
# Optimization [1]: Current loss: 0.006366105872397624
# Optimization [101]: Current loss: 0.006244419879875915
# Optimization [201]: Current loss: 0.006240783369771324
# Optimization [301]: Current loss: 0.006239888015024112
# Optimization terminated successfully.
#          Current function value: 0.006240
#          Iterations: 216
#          Function evaluations: 328
# [0]: Running H optimizer for replicate 2
# Optimization [1]: Current loss: 0.003712467995344903
# Optimization [101]: Current loss: 0.003701122679761926
# Optimization [201]: Current loss: 0.0037004691576196197
# Optimization terminated successfully.
#          Current function value: 0.003700
#          Iterations: 166
#          Function evaluations: 256
# [0]: Done.
# [0]: Running iterative updates and combined deconvolution for F, N, and B
# 00:02:05.283
# mu0_1         -1.336088
# lambda_1      74.783963
# delta_1        0.014744
# sigma0_1       4.425889
# sigmav_1       0.111217
# gamma1_1       0.306319
# gamma2_1       0.461718
# halted_1       0.256119
# mu0_2          8.016421
# lambda_2      73.853784
# delta_2        0.000220
# sigma0_2       1.000885
# sigmav_2       0.193300
# gamma1_2       0.349747
# gamma2_2       0.644016
# halted_2       0.335612
# opt_H_rn_1     0.006240
# opt_H_rn_2     0.003700
# F_rn           0.005161
# Name: 0, dtype: float64
# Epoch: 1
# [1]: Running H optimizer for replicate 1
# Optimization [1]: Current loss: 0.006331216564049824
# Optimization [101]: Current loss: 0.006239092998370022
# Optimization [201]: Current loss: 0.006234212170688833
# Optimization terminated successfully.
#          Current function value: 0.006234
#          Iterations: 143
#          Function evaluations: 232
# [1]: Running H optimizer for replicate 2
# Optimization [1]: Current loss: 0.003912819625171412
# Optimization [101]: Current loss: 0.0039024252902070755
# Optimization [201]: Current loss: 0.0039021625583608006
# Optimization terminated successfully.
#          Current function value: 0.003902
#          Iterations: 140
#          Function evaluations: 227
# [1]: Done.
# [1]: Running iterative updates and combined deconvolution for F, N, and B
# 00:03:42.881
# mu0_1         -1.753633
# lambda_1      74.430282
# delta_1        0.013960
# sigma0_1       4.035053
# sigmav_1       0.115926
# gamma1_1       0.305981
# gamma2_1       0.459602
# halted_1       0.223769
# mu0_2          8.255194
# lambda_2      73.949646
# delta_2        0.000214
# sigma0_2       1.000632
# sigmav_2       0.194131
# gamma1_2       0.355993
# gamma2_2       0.735551
# halted_2       0.322487
# opt_H_rn_1     0.006234
# opt_H_rn_2     0.003902
# F_rn           0.005082
# Name: 1, dtype: float64
# Epoch: 2
# [2]: Running H optimizer for replicate 1
# Optimization [1]: Current loss: 0.006201821177579143
# Optimization [101]: Current loss: 0.006130995900380182
# Optimization [201]: Current loss: 0.0061291924439366855
# Optimization terminated successfully.
#          Current function value: 0.006129
#          Iterations: 182
#          Function evaluations: 279
# [2]: Running H optimizer for replicate 2
# Optimization [1]: Current loss: 0.00388784227641212
# Optimization [101]: Current loss: 0.0038814094731771296
# Optimization [201]: Current loss: 0.003880798209747334
# Optimization terminated successfully.
#          Current function value: 0.003881
#          Iterations: 176
#          Function evaluations: 268
# [2]: Done.
# [2]: Running iterative updates and combined deconvolution for F, N, and B
# 00:05:39.001
# mu0_1         -2.148360
# lambda_1      74.071700
# delta_1        0.013190
# sigma0_1       3.984710
# sigmav_1       0.119026
# gamma1_1       0.306210
# gamma2_1       0.416532
# halted_1       0.190506
# mu0_2          8.539472
# lambda_2      74.095767
# delta_2        0.000222
# sigma0_2       1.000125
# sigmav_2       0.194974
# gamma1_2       0.361388
# gamma2_2       0.831164
# halted_2       0.310741
# opt_H_rn_1     0.006129
# opt_H_rn_2     0.003881
# F_rn           0.005674
# Name: 2, dtype: float64
# Epoch: 3
# [3]: Running H optimizer for replicate 1
# Optimization [1]: Current loss: 0.006851787178274879
# Optimization [101]: Current loss: 0.0067445671611079646
# Optimization [201]: Current loss: 0.006739596192993621
# Optimization terminated successfully.
#          Current function value: 0.006740
#          Iterations: 129
#          Function evaluations: 215
# [3]: Running H optimizer for replicate 2
# Optimization [1]: Current loss: 0.00441677481586699
# Optimization [101]: Current loss: 0.004407500729646233
# Optimization [201]: Current loss: 0.004406824322999794
# Optimization terminated successfully.
#          Current function value: 0.004407
#          Iterations: 142
#          Function evaluations: 226
# [3]: Done.
# [3]: Running iterative updates and combined deconvolution for F, N, and B
# 00:07:14.551
# mu0_1         -2.299993
# lambda_1      73.865526
# delta_1        0.014441
# sigma0_1       3.080087
# sigmav_1       0.122791
# gamma1_1       0.305478
# gamma2_1       0.451252
# halted_1       0.164397
# mu0_2          9.015034
# lambda_2      74.394390
# delta_2        0.000224
# sigma0_2       1.000001
# sigmav_2       0.195683
# gamma1_2       0.366572
# gamma2_2       0.895769
# halted_2       0.300219
# opt_H_rn_1     0.006740
# opt_H_rn_2     0.004407
# F_rn           0.005189
# Name: 3, dtype: float64
# Epoch: 4
# [4]: Running H optimizer for replicate 1
# Optimization [1]: Current loss: 0.006245638564582142
# Optimization [101]: Current loss: 0.006183124135083998
# Optimization terminated successfully.
#          Current function value: 0.006182
#          Iterations: 123
#          Function evaluations: 197
# [4]: Running H optimizer for replicate 2
# Optimization [1]: Current loss: 0.004062886385286491
# Optimization [101]: Current loss: 0.004053221381997582
# Optimization terminated successfully.
#          Current function value: 0.004053
#          Iterations: 103
#          Function evaluations: 172
# [4]: Done.
# [4]: Running iterative updates and combined deconvolution for F, N, and B
# 00:08:33.812
# mu0_1         -2.519104
# lambda_1      73.580524
# delta_1        0.014177
# sigma0_1       3.340767
# sigmav_1       0.123911
# gamma1_1       0.306504
# gamma2_1       0.478460
# halted_1       0.130749
# mu0_2          9.367312
# lambda_2      74.572731
# delta_2        0.000240
# sigma0_2       1.000209
# sigmav_2       0.196838
# gamma1_2       0.372076
# gamma2_2       0.888112
# halted_2       0.285748
# opt_H_rn_1     0.006182
# opt_H_rn_2     0.004053
# F_rn           0.004966
# Name: 4, dtype: float64

# %%
combined_deconv.real_deconv1.plot_heatmaps()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 combined_deconv.real_deconv1.plot_heatmaps()
#
# File ~/Research/deconvolution-python/src/RealDataReplication.py:126, in RealDataReplicationDeconvolution.plot_heatmaps(self)
#     125 def plot_heatmaps(self):
# --> 126 	N, F, G, B, H = self.N, self.F, self.G, self.B, self.H
#     128 	fig = plot_heatmaps(N, F, H, B, G, column_names=self.masked_G_df.columns,
#     129 		full_column_names=self.G_df.columns)
#     130 	plt.suptitle(f"Replication {self.replicate}"
#     131 		f" deconvolution,\nChromosome {self.chrom}")
#
# AttributeError: 'RealDataReplicationDeconvolution' object has no attribute 'N'

# %%
combined_deconv.plot_heatmaps()
