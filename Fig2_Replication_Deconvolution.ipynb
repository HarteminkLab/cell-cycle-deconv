# %% [markdown]
# # Figure 2 - Replication Deconvolution

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.Figure2_Replication import Figure2ReplicationDeconvolution

output_dir = 'output/draft3_run/'
fig2 = Figure2ReplicationDeconvolution(output_dir)

# %%
# Create a figure depicting the objective NHFB = G

# %%
# Examine the replication data, does replicate 2's cell cycle length need to be longer?

from src.RealDataReplication import RealDataReplicationDeconvolution
from src.config import load_cloccs_configs

config1, config2 = load_cloccs_configs()

real1 = RealDataReplicationDeconvolution(config1, 4, 1)
real1.load_replicate_data(4, 1)
real1.setup_deconvolution()
# Out:
# Omit windows with less than 75% read coverage.
# Omit windows with less than 75% read coverage.
# Deconvolving 702 regions
# Initializing B using timepoint 0

# %%
# Conserve space
del real1.mnase_loader.mnase_reads

# %%
real2 = RealDataReplicationDeconvolution(config2, 4, 2)
real2.load_replicate_data(4, 2)
real2.setup_deconvolution()
# Out:
# Omit windows with less than 75% read coverage.
# Omit windows with less than 75% read coverage.
# Deconvolving 704 regions
# Initializing B using timepoint 0

# %%
# Conserve space
del real2.mnase_loader.mnase_reads

# %%
real2.plot_G()
plot_raw_timepoints(config2, flip=True, s_color='green', lw=1.)

# %%
real1.plot_G()
plot_raw_timepoints(config1, flip=True, s_color='green', lw=1.)
