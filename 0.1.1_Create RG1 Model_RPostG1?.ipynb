# %% [markdown]
# # Recovery PostG1 Model Creation
#
# We have an RG1 model that appears to run well, the question now is does the recovery need it's own post-G1 phase as well.
#
# The motivation is that the gene expression for RNR1 for postG1 is much higher in recovery than any other timepoint.
#
# There are examples of other fits that could use some improving as well...
#
# This would affect gene expression and chromatin fits. It's the most clear in gene expression deconvolution because we are just looking at a single value.
#
# # This Notebook - Create Recovery Post-G1 Model
#
# For this notebook, we will try to create this model and see if we can do a deconvolution and improve the fit for RNR1.

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from src.create_model_rg1_rpostg1 import create_model_rg1_rpostg1, get_model_cfg_str

output_model_path = 'models/yl_cell_cycle/wt2_rg1_rpostg1.label'
posteriors_filepath = 'data/cloccs_output_yl_replicate2/posteriors.txt'

wt2_params, rep2_model = create_model_rg1_rpostg1(posteriors_filepath)
wt2_cfg = get_model_cfg_str(wt2_params, rep2_model)

with open(output_model_path, 'w') as f:
    f.write(wt2_cfg)

from src.ModelFile import ModelFile

model_file = ModelFile()
model_file.load_model(output_model_path)
model_file.plot_model()
