# %% [markdown]
# # No smoothing example
# February 13, 2024

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from cc_src.chromatin_model import ChromatinModel
from src.config import load_yl_replicate1_rg1_alpha_vst_config

gene_name = 'CLB2'
config1 = load_yl_replicate1_rg1_alpha_vst_config()
chromatin_model = ChromatinModel(config1)
chromatin_model.load_mnase_gene(gene_name, 1)
# Out:
# Loading MNase reads for CLB2...Done.

# %%
chromatin_model.create_deconvolution_bins(smoothing=False)
# Out:
# Unflattened the input data is of shape: (16, 15, 50)
# The size of our input data, G is: (16, 750)

# %%
chromatin_model.plot_bin_comparison()

# %%
chromatin_model.gamma = 0.01

# %%
from src.deconvolve_chromatin import deconvolve_chromatin_H
import cvxpy

chromatin_model.deconvolve(solver=cvxpy.MOSEK, verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.4.1
# ===============================================================================
# (CVXPY) Feb 13 02:03:55 PM: Your problem has 170250 variables, 1 constraints, and 0 parameters.
# (CVXPY) Feb 13 02:03:55 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 13 02:03:55 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 13 02:03:55 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Feb 13 02:03:55 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 13 02:03:55 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Feb 13 02:03:55 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Feb 13 02:03:55 PM: Applying reduction Dcp2Cone
# (CVXPY) Feb 13 02:03:55 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 13 02:03:55 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Feb 13 02:04:12 PM: Applying reduction MOSEK
# (CVXPY) Feb 13 02:04:24 PM: Finished problem compilation (took 2.828e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 13 02:04:24 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Feb 13 02:04:46 PM: Problem
# (CVXPY) Feb 13 02:04:46 PM:   Name                   :
# (CVXPY) Feb 13 02:04:46 PM:   Objective sense        : maximize
# (CVXPY) Feb 13 02:04:46 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Feb 13 02:04:46 PM:   Constraints            : 746251
# (CVXPY) Feb 13 02:04:46 PM:   Affine conic cons.     : 0
# (CVXPY) Feb 13 02:04:46 PM:   Disjunctive cons.      : 0
# (CVXPY) Feb 13 02:04:46 PM:   Cones                  : 1
# (CVXPY) Feb 13 02:04:46 PM:   Scalar variables       : 1334252
# (CVXPY) Feb 13 02:04:46 PM:   Matrix variables       : 0
# (CVXPY) Feb 13 02:04:46 PM:   Integer variables      : 0
# (CVXPY) Feb 13 02:04:46 PM:
# (CVXPY) Feb 13 02:04:46 PM: Optimizer started.
# (CVXPY) Feb 13 02:04:48 PM: Presolve started.
# (CVXPY) Feb 13 02:04:49 PM: Linear dependency checker started.
# (CVXPY) Feb 13 02:04:49 PM: Linear dependency checker terminated.
# (CVXPY) Feb 13 02:04:49 PM: Eliminator started.
# (CVXPY) Feb 13 02:04:55 PM: Freed constraints in eliminator : 553500
# (CVXPY) Feb 13 02:04:55 PM: Eliminator terminated.
# (CVXPY) Feb 13 02:04:57 PM: Eliminator started.
# (CVXPY) Feb 13 02:04:59 PM: Freed constraints in eliminator : 0
# (CVXPY) Feb 13 02:04:59 PM: Eliminator terminated.
# (CVXPY) Feb 13 02:05:00 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Feb 13 02:05:00 PM: Lin. dep.  - tries                  : 1                 time                   : 0.35
# (CVXPY) Feb 13 02:05:00 PM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Feb 13 02:05:00 PM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY
PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Feb 13 02:05:27 PM:   Solution status : OPTIMAL
# (CVXPY) Feb 13 02:05:27 PM:   Primal.  obj: 4.4719775159e+03    nrm: 1e+04    Viol.  con: 5e-06    var: 1e+02    cones: 0e+00
# (CVXPY) Feb 13 02:05:27 PM:   Dual.    obj: 4.4719777527e+03    nrm: 4e+03    Viol.  con: 0e+00    var: 9e-13    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 13 02:05:28 PM: Problem status: optimal
# (CVXPY) Feb 13 02:05:28 PM: Optimal value: 4.435e+03
# (CVXPY) Feb 13 02:05:28 PM: Compilation took 2.828e+01 seconds
# (CVXPY) Feb 13 02:05:28 PM: Solver (including time spent in interface) took 6.333e+01 seconds
# Deconvolved in : 00:01:33.05
# The fitting norm is 5.77, the smoothing norm is: 9.21

# %%
fig = chromatin_model.plot_prediction_comparison()

# %%
chromatin_model.plot_halted_f_img()

# %%
from src.model import Model
ge1_model = Model(config1, gene_name)

# %%
ge1_model.deconvolve_find_optimal_gamma()

# %%
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(ge_model=ge1_model, 
    vmax=10)

# %%
chromatin_model.deconvolve_find_optimal_gamma()
# Out:
# Running the find optimal gamma procedure...
#   ... The base fitting norm (rn) with no smoothing (gamma=0) is: 5.5292
#   ... Searching for an optimal gamma value in the boundaries: [0.0001, 0.0100]
#   ...  search left, rn_goal = 5.6092, rate = 1.4
#   ...  search right, rn_goal = 7.7409, rate = 40.0
#   ... rn range: [5.6452, 5.7664]
#   ... search gamma in [0.0001 0.0100] for elbow
#   ...   gm = 0.0001, rn = 5.6452, rate = 2.10, time = 00:05:13.48
#   ...   gm = 0.0011, rn = 5.6596, rate = 2.36, time = 00:06:42.02
#   ...   gm = 0.0021, rn = 5.6730, rate = 2.60, time = 00:08:07.96
#   ...   gm = 0.0031, rn = 5.6980, rate = 3.05, time = 00:09:33.21
#   ...   gm = 0.0041, rn = 5.7132, rate = 3.33, time = 00:10:59.01
#   ...   gm = 0.0050, rn = 5.7244, rate = 3.53, time = 00:12:44.02
#   ...   gm = 0.0060, rn = 5.7297, rate = 3.63, time = 00:14:10.14
#   ...   gm = 0.0070, rn = 5.7447, rate = 3.90, time = 00:15:35.54
#   ...   gm = 0.0080, rn = 5.7538, rate = 4.06, time = 00:17:02.47
#   ...   gm = 0.0090, rn = 5.7657, rate = 4.28, time = 00:18:30.68
#   ...   gm = 0.0100, rn = 5.7664, rate = 4.29, time = 00:19:59.01
# The x_grad1 is: [0.01446824 0.01391567 0.01918241 0.02010282 0.01322492 0.0082512
#  0.01013808 0.01205118 0.01051174 0.00629319 0.00064559]
# The x_grad2 is: [-0.00055256  0.00235709  0.00309357 -0.00297875 -0.00592581 -0.00154342
#   0.00189999  0.00018683 -0.002879   -0.00493308 -0.0056476 ]
# The curvature is: [ 6.87374225e-05  3.32148777e-04  2.32791161e-03  1.49179886e-03
#   6.37422091e-04  2.00261285e-03  5.16580185e-03  2.79074521e-03
#  -4.16998813e-04 -1.41388015e-02 -1.28285909e-01]
# YPR119W: ... final gamma = 0.00604
# Time to find optimal gamma: 00:21:30.20
# Deconvolved in : 00:21:30.85
# The fitting norm is 5.73, the smoothing norm is: 11.30

# %%
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(ge_model=ge1_model, 
    vmax=10, smooth=False)

# %%
gene_name = 'DSE1'
chromatin_model.load_mnase_gene(gene_name, 1)
chromatin_model.create_deconvolution_bins(smoothing=False)
chromatin_model.gamma = 0.006
chromatin_model.deconvolve()
ge1_model = Model(config1, gene_name)
ge1_model.deconvolve_find_optimal_gamma()
# Out:
# Loading MNase reads for DSE1...Done.
# Unflattened the input data is of shape: (16, 16, 50)
# The size of our input data, G is: (16, 800)
# Deconvolved in : 00:01:28.82
# The fitting norm is 5.39, the smoothing norm is: 8.16

# %%
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(vmax=10, ge_model=ge1_model)

# %%
chromatin_model.plot_prediction_comparison()

# %%
ge1_model.plot_deconvolved_gene()

# %%
gene_name = 'CHS2'
chromatin_model.load_mnase_gene(gene_name, 1)
chromatin_model.create_deconvolution_bins(smoothing=False)
chromatin_model.gamma = 0.01
chromatin_model.deconvolve()
ge1_model = Model(config1, gene_name)
ge1_model.deconvolve_find_optimal_gamma()
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(vmax=10, ge_model=ge1_model)
# Out:
# Loading MNase reads for CHS2...Done.
# Unflattened the input data is of shape: (16, 15, 50)
# The size of our input data, G is: (16, 750)
# Deconvolved in : 00:01:19.54
# The fitting norm is 4.68, the smoothing norm is: 7.80

# %%
gene_name = 'MRH1'
chromatin_model.load_mnase_gene(gene_name, 1)
chromatin_model.create_deconvolution_bins(smoothing=False)
chromatin_model.gamma = 0.01
chromatin_model.deconvolve()
ge1_model = Model(config1, gene_name)
ge1_model.deconvolve_find_optimal_gamma()
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(vmax=10, ge_model=ge1_model)
# Out:
# Loading MNase reads for MRH1...Done.
# Unflattened the input data is of shape: (16, 15, 50)
# The size of our input data, G is: (16, 750)
# Deconvolved in : 00:01:23.51
# The fitting norm is 5.58, the smoothing norm is: 9.32

# %%
gene_name = 'DBF2'
chromatin_model.load_mnase_gene(gene_name, 1)
chromatin_model.create_deconvolution_bins(smoothing=False)
chromatin_model.gamma = 0.01
chromatin_model.deconvolve()
ge1_model = Model(config1, gene_name)
ge1_model.deconvolve_find_optimal_gamma()
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(vmax=10, ge_model=ge1_model)
# Out:
# Loading MNase reads for DBF2...Done.
# Unflattened the input data is of shape: (16, 15, 50)
# The size of our input data, G is: (16, 750)
# Deconvolved in : 00:01:18.17
# The fitting norm is 5.09, the smoothing norm is: 6.97

# %%
gene_name = 'HTB2'
chromatin_model.load_mnase_gene(gene_name, 1)
chromatin_model.create_deconvolution_bins(smoothing=False)
chromatin_model.gamma = 0.01
chromatin_model.deconvolve()
ge1_model = Model(config1, gene_name)
ge1_model.deconvolve_find_optimal_gamma()
fig = chromatin_model.create_deconvolution_plots_abbreviated_flipped(vmax=10, ge_model=ge1_model)
# Out:
# Loading MNase reads for HTB2...Done.
# Unflattened the input data is of shape: (16, 15, 50)
# The size of our input data, G is: (16, 750)
# Deconvolved in : 00:01:17.45
# The fitting norm is 5.25, the smoothing norm is: 7.28
