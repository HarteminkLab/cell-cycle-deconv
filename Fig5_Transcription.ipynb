# %% [markdown]
# # Figure 5 - Transcription-linked Chromatin Deconvolution Results

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pipeline.figure_chromatin_metrics import FigureChromatinMetrics

fig_metrics = FigureChromatinMetrics(output_dir='output/draft4_run/')

# %%
fig_metrics.setup_processor()

# %%
from pipeline.expression_analysis import load_deconvolved_gene_expression

loaded_expression = load_deconvolved_gene_expression('output/draft4_run/', include_nongenic=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 3
#       1 from pipeline.expression_analysis import load_deconvolved_gene_expression
# ----> 3 loaded_expression = load_deconvolved_gene_expression('output/draft4_run/', include_nongenic=True)
#
# File ~/Research/deconvolution-python/pipeline/expression_analysis.py:116, in load_deconvolved_gene_expression(output_directory, include_nongenic)
#     113 from src.sgd import get_gene_name_orf_name
#     115 # Load the transcripts to be loaded
# --> 116 combined_gene_nongenic = load_transcripts_sets(output_directory, combined=True)
#     118 genes = get_deconvolved_geneset()
#     120 file_directory = f"{output_directory}/genes_deconvolution/"
#
# File ~/Research/deconvolution-python/src/transcripts_dataset.py:330, in load_transcripts_sets(output_dir, combined, genes_path, nongenes_path)
#     318 	plt.axvline(threshold, c='red', alpha=0.75)
#     319 	plt.axvline(-threshold, c='red', alpha=0.75)
#     321 # def load_transcripts_sets(output_dir, combined=False):
#     322 # 	geneset = pd.read_csv(f"{output_dir}/transcripts_calling/updated_transcripts_geneset.csv")
#     323 # 	nongenic_set = pd.read_csv(f"{output_dir}/transcripts_calling/nongenic_transcripts_set.csv")
#     324 # 	geneset = geneset.set_index('orf_name')
#     325
#     326 # 	nongenic_set = nongenic_set.set_index('transcript_name').rename(columns={'end': 'stop'})
#     327 # 	nongenic_set['length'] = nongenic_set.stop - nongenic_set.start
#     328
#     329 # 	# ----------- Non-genic absolute boundaries ---------------------------
# --> 330
#     331 # 	# Full transcript for non-genes are defined by the start and stop
#     332 # 	nongenic_set['full_transcript_start'] = nongenic_set['start']
#     333 # 	nongenic_set['full_transcript_end'] = nongenic_set['stop']
#     334
#     335 # 	# ------- For the genes use TSS and PAS to define boundaries -----------
#     336
#     337 # 	geneset['transcript_class'] = 'genic'
#     338 # 	# Add keys for full transcript ends, using the TSS and PAS's
#     339 # 	# We can use the promoter and transcript boundaries, as they are derived from these locations
#     340 # 	sel_watson_transcripts = geneset.strand == '+'
#     341 # 	sel_crick_transcripts = geneset.strand == '-'
#     342
#     343 # 	# Watson strand definitions
#     344 # 	geneset.loc[sel_watson_transcripts, 'full_transcript_start'] = \
#     345 # 		geneset.loc[sel_watson_transcripts, 'TSS']
#     346 # 	geneset.loc[sel_watson_transcripts, 'full_transcript_end'] = \
#     347 # 		geneset.loc[sel_watson_transcripts, 'PAS']
#     348
#     349 # 	# Crick strand definitions
#     350 # 	geneset.loc[sel_crick_transcripts, 'full_transcript_end'] = \
#     351 # 		geneset.loc[sel_crick_transcripts, 'TSS']
#     352 # 	geneset.loc[sel_crick_transcripts, 'full_transcript_start'] = \
#     353 # 		geneset.loc[sel_crick_transcripts, 'PAS']
#     354
#     355 # 	def set_bound_type_int(dat):
#     356 # 		dat.full_transcript_start = dat.full_transcript_start.astype(int)
#     357
#     358 # 	set_bound_type_int(geneset)
#     359 # 	set_bound_type_int(nongenic_set)
#     360
#     361 # 	# -------------------------------------------------------------------------
#     362
#     363 # 	# Combined dataset with common keys
#     364 # 	if combined:
#     365 # 		preserve_keys = ['transcript_class',
#     366 # 						 'chr', 'strand', 'start', 'stop', 'length',
#     367 # 						 'promoter_start', 'promoter_end',
#     368 # 						 'gene_body_start', 'gene_body_end',
#     369 # 						 'full_transcript_start', 'full_transcript_end'
#     370 # 		]
#     371
#     372 # 		nongenic_set = nongenic_set.rename(columns={'transcript_body_start': 'gene_body_start',
#     373 # 			'transcript_body_end': 'gene_body_end'})
#     374 # 		nongenic_set['transcript_class'] = 'nongenic'
#     375
#     376 # 		combined_gene_nongenic = pd.concat([geneset[preserve_keys], nongenic_set[preserve_keys]])
#     377
#     378 # 		return combined_gene_nongenic
#     379
#     380 # 	return geneset, nongenic_set
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/opt/anaconda3/envs/cell-cycle-deconvolution/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/draft4_run//transcripts_calling/nongenic_transcripts_set.csv'

# %%
fig_metrics.setup_integration()

# %%
fig_metrics.generate_figures_and_panel()

# %%
fig_metrics.create_gene_group_trajectories_plots()

# %%
from IPython.display import Image, display

# %%
fig_metrics.layout_trajectories_panel()
display(Image(f'output/draft4_run/Figures/Debug/Figure4_Chromatin_Metrics_debug.png'))

# %%
fig_metrics.layout_genesets_panel()
display(Image(f'output/draft4_run/Figures/Debug/Figure5_Genesets_debug.png'))

# %%
fig_metrics.layout_supplemental_panel()
display(Image(f'output/draft4_run/Figures/Debug/Supplemental5_Chromatin_Metrics_debug.png'))

# %%
fig_metrics.create_locus_plots()

# %%
fig_metrics.create_integration_plots()

# %%
#fig_metrics.integration.plot_all_trajectory_area_cell_cycle_genes()

# %%
fig_metrics.layout_chromatin_transcription_ptrs()
display(Image(f'output/draft4_run/Figures/Debug/Supplemental6_Chromatin_Transcription_debug.png'))

# %%
fig_metrics.layout_mcm_panel()
display(Image(f'output/draft4_run/Figures/Debug/Supplemental7_MCM_Panel_debug.png'))
