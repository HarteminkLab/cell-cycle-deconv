# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import torch
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
from pysrc.analyze_models import Model

model = Model()

# %%
import os

models_directory = 'models/wt1_flow/'
files = os.listdir(models_directory)

for f in files:
    model_path = (models_directory + f)
    model.load_model(model_path)
    model.plot_model()

# %%
f_data = pd.read_csv('YPR119W.100runs.f', sep='\t', header=None).values[0]

# %%
f_data.shape
plt.plot(np.log(f_data))
