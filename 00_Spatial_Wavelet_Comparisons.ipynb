# %% [markdown]
# # Scratch space for understanding spatial wavelets for image decompression
# February 13, 2024

# %%
# Preamble, notebook setup and imports

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from cc_src.chromatin_model import ChromatinModel
from src.config import load_yl_replicate1_rg1_alpha_vst_config

gene_name = 'CLB2'
config1 = load_yl_replicate1_rg1_alpha_vst_config()
chromatin_model = ChromatinModel(config1)
chromatin_model.load_mnase_gene(gene_name, 1)
# Out:
# Loading MNase reads for CLB2...Done.

# %%
chromatin_model.create_deconvolution_bins(smoothing=False)
# Out:
# Unflattened the input data is of shape: (16, 16, 50)
# The size of our input data, G is: (16, 800)

# %%
from src.wavelet_im_smoothing import ChromatinWaveletsComparison

chrom_wavelets = ChromatinWaveletsComparison(chromatin_model)

# %%
gen = chrom_wavelets.wavelet_generators[0][0]
gen.plot_img(gen.img)

# %%
chrom_wavelets.create_coefficients('db4')
chrom_wavelets.plot_thresholds()

chrom_wavelets.create_coefficients('bior4.4')
chrom_wavelets.plot_thresholds()

chrom_wavelets.create_coefficients('sym4')
chrom_wavelets.plot_thresholds()

chrom_wavelets.create_coefficients('coif4')
chrom_wavelets.plot_thresholds()
